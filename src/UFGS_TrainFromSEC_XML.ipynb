# %% [markdown]
# <a href="https://colab.research.google.com/github/vdubya/critria-assistant/blob/main/UFGS_TrainFromSECXML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Process XML and PDF files

# %%
# Install necessary libraries
# !pip install pymupdf requests transformers lxml

import fitz  # PyMuPDF
import zipfile
import requests
import os
import json
from lxml import etree  # For parsing XML
from transformers import LayoutLMTokenizer

# Enable debugging
DEBUG = True

# Helper function for debug prints
def debug_print(message, separator="--- "):
    if DEBUG:
        print(f"{separator}{message}")

# Step 1: Download and Extract the SEC File from the ZIP
def download_and_extract_sec(zip_url, target_file):
    print("\n****** Downloading and Extracting SEC File")

    zip_path = "/content/UFGS_M.zip"
    extracted_sec_path = None

    # Download the ZIP file
    debug_print(f"Downloading ZIP file from: {zip_url}")
    response = requests.get(zip_url)
    with open(zip_path, "wb") as f:
        f.write(response.content)
    debug_print(f"Downloaded ZIP file saved at: {zip_path}")

    # Extract the target SEC file
    debug_print(f"Extracting SEC file: {target_file}")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        for file in zip_ref.namelist():
            if file.endswith(target_file):  # Focus on the specified SEC file
                extracted_sec_path = f"/content/{target_file}"
                with zip_ref.open(file) as sec_file:
                    with open(extracted_sec_path, "wb") as f:
                        f.write(sec_file.read())
    debug_print(f"Extracted SEC file saved at: {extracted_sec_path}")

    return extracted_sec_path

# Step 2: Parse the XML File and Extract Hierarchical Structure
def parse_xml(xml_path):
    print("\n****** Parsing XML File")
    tree = etree.parse(xml_path)
    root = tree.getroot()

    def recursive_parse(element):
        children = [recursive_parse(child) for child in element]
        return {
            "tag": element.tag,
            "text": (element.text or "").strip(),
            "children": children
        }

    parsed_hierarchy = recursive_parse(root)
    debug_print(f"Parsed XML hierarchy:\n{json.dumps(parsed_hierarchy, indent=4)}")
    return parsed_hierarchy

# Step 3: Download the PDF File
def download_pdf(pdf_url, pdf_name):
    print("\n****** Downloading PDF File")

    pdf_path = f"/content/{pdf_name}"
    debug_print(f"Downloading PDF file from: {pdf_url}")
    response = requests.get(pdf_url)
    with open(pdf_path, "wb") as f:
        f.write(response.content)
    debug_print(f"Downloaded PDF file saved at: {pdf_path}")

    return pdf_path

# Step 4: Extract Text and Bounding Boxes from the PDF
def extract_text_and_bboxes(pdf_path):
    print("\n****** Extracting Text and Bounding Boxes from PDF")

    doc = fitz.open(pdf_path)  # Open the PDF
    data = []  # List to store extracted data

    for page_number in range(len(doc)):
        debug_print(f"\n================\nProcessing page {page_number + 1}/{len(doc)}")
        page = doc[page_number]
        page_width, page_height = page.rect.width, page.rect.height  # Get page dimensions

        # Extract text blocks with bounding boxes
        blocks = page.get_text("blocks")
        debug_print(f"* Found {len(blocks)} text blocks on page {page_number + 1}")
        for block in blocks:
            if len(block) >= 5:  # Ensure there is at least text and bounding box data
                x0, y0, x1, y1, text = block[:5]  # Unpack first 5 elements
                if text.strip():  # Ignore empty blocks
                    normalized_bbox = normalize_bbox([x0, y0, x1, y1], page_width, page_height)
                    data.append({
                        "page": page_number + 1,  # Add page number here
                        "text": text.strip(),
                        "bbox": [x0, y0, x1, y1],  # Original bounding box
                        "normalized_bbox": normalized_bbox
                    })
                    debug_print(f"----\n* Extracted block: \n{text.strip()}\n"
                                f"* Original BBox: {[x0, y0, x1, y1]}\n"
                                f"* Normalized BBox: {normalized_bbox}")

    return data

# Step 5: Normalize Bounding Boxes to LayoutLM's Input Scale (0-1000)
def normalize_bbox(bbox, page_width, page_height):
    return [
        int(1000 * bbox[0] / page_width),
        int(1000 * bbox[1] / page_height),
        int(1000 * bbox[2] / page_width),
        int(1000 * bbox[3] / page_height)
    ]

# Step 6: Align XML Content with PDF Text
def align_xml_with_pdf(xml_hierarchy, pdf_data):
    print("\n****** Aligning XML Content with PDF Text")

    aligned_data = []

    def recursive_align(xml_element, pdf_data_iter):
        aligned_children = []
        for child in xml_element["children"]:
            aligned_child = recursive_align(child, pdf_data_iter)
            aligned_children.append(aligned_child)

        # Attempt to align current XML text with PDF text
        try:
            pdf_item = next(pdf_data_iter)
        except StopIteration:
            pdf_item = {"page": None, "text": None, "bbox": None, "normalized_bbox": None}

        return {
            "tag": xml_element["tag"],
            "xml_text": xml_element["text"],
            "pdf_text": pdf_item["text"],
            "page": pdf_item["page"],  # Include page number here
            "bbox": pdf_item["bbox"],
            "normalized_bbox": pdf_item["normalized_bbox"],
            "children": aligned_children
        }

    pdf_data_iter = iter(pdf_data)
    aligned_hierarchy = recursive_align(xml_hierarchy, pdf_data_iter)
    debug_print(f"Aligned XML-PDF hierarchy:\n{json.dumps(aligned_hierarchy, indent=4)}")
    return aligned_hierarchy

# Step 7: Save Aligned Data for Review
def save_aligned_data(data, output_path):
    print("\n****** Saving Aligned Data")
    debug_print(f"Saving aligned data to: {output_path}")
    with open(output_path, "w") as f:
        json.dump(data, f, indent=4)
    debug_print(f"Data saved successfully at: {output_path}")

# Main Execution
sec_zip_url = "https://www.wbdg.org/FFC/DOD/UFGS/UFGS_M.zip"
target_sec_file = "00 01 15.SEC"
pdf_url = "https://www.wbdg.org/FFC/DOD/UFGS/UFGS%2000%2001%2015.pdf"
pdf_name = "UFGS_00_01_15.pdf"

# Download and extract the SEC file
extracted_sec_path = download_and_extract_sec(sec_zip_url, target_sec_file)

# Parse the XML file and extract the hierarchy
xml_hierarchy = parse_xml(extracted_sec_path)

# Download the corresponding PDF file
pdf_path = download_pdf(pdf_url, pdf_name)

# Extract text and bounding boxes from the PDF
pdf_data = extract_text_and_bboxes(pdf_path)

# Align XML with PDF content
aligned_data = align_xml_with_pdf(xml_hierarchy, pdf_data)

# Save the aligned data for review
output_json_path = "/content/aligned_data_with_pages.json"
save_aligned_data(aligned_data, output_json_path)

# Print a summary
print("\n****** Summary")
print(f"Aligned XML-PDF data saved at: {output_json_path}")
# Out:
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.10/dist-packages (1.24.14)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (5.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
#
# ****** Downloading and Extracting SEC File
# --- Downloading ZIP file from: https://www.wbdg.org/FFC/DOD/UFGS/UFGS_M.zip
# --- Downloaded ZIP file saved at: /content/UFGS_M.zip
# --- Extracting SEC file: 00 01 15.SEC
# --- Extracted SEC file saved at: /content/00 01 15.SEC
#
# ****** Parsing XML File
# --- Parsed XML hierarchy:
# {
#     "tag": "SEC",
#     "text": "",
#     "children": [
#         {
#             "tag": "MTA",
#             "text": "",
#             "children": []
#         },
#         {
#             "tag": "MTA",
#             "text": "",
#             "children": []
#         },
#         {
#             "tag": "HDR",
#             "text": "",
#             "children": [
#                 {
#                     "tag": "AST",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "TAB",
#                     "text": "",
#                     "children": [
#                         {
#                             "tag": "WBK",
#                             "text": "",
#                             "children": [
#                                 {
#                                     "tag": "STS",
#                                     "text": "",
#                                     "children": [
#                                         {
#                                             "tag": "STY",
#                                             "text": "",
#                                             "children": [
#                                                 {
#                                                     "tag": "ALN",
#                                                     "text": "",
#                                                     "children": []
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "tag": "TDA",
#                                     "text": "",
#                                     "children": [
#                                         {
#                                             "tag": "COL",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "COL",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "ROW",
#                                             "text": "",
#                                             "children": [
#                                                 {
#                                                     "tag": "CEL",
#                                                     "text": "",
#                                                     "children": [
#                                                         {
#                                                             "tag": "DTA",
#                                                             "text": "USACE / NAVFAC / AFCEC",
#                                                             "children": []
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "tag": "CEL",
#                                                     "text": "",
#                                                     "children": [
#                                                         {
#                                                             "tag": "DTA",
#                                                             "text": "00 01 15 (February 2024)",
#                                                             "children": []
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "tag": "ROW",
#                                             "text": "",
#                                             "children": [
#                                                 {
#                                                     "tag": "CEL",
#                                                     "text": "",
#                                                     "children": []
#                                                 },
#                                                 {
#                                                     "tag": "CEL",
#                                                     "text": "",
#                                                     "children": []
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "tag": "ROW",
#                                             "text": "",
#                                             "children": [
#                                                 {
#                                                     "tag": "CEL",
#                                                     "text": "",
#                                                     "children": [
#                                                         {
#                                                             "tag": "DTA",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "HL3",
#                                                                     "text": "------------------------------------",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "tag": "ROW",
#                                             "text": "",
#                                             "children": [
#                                                 {
#                                                     "tag": "CEL",
#                                                     "text": "",
#                                                     "children": [
#                                                         {
#                                                             "tag": "DTA",
#                                                             "text": "Preparing Activity:",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "PRA",
#                                                                     "text": "NAVFAC",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "tag": "CEL",
#                                                     "text": "",
#                                                     "children": [
#                                                         {
#                                                             "tag": "DTA",
#                                                             "text": "Superseding",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "BRK",
#                                                                     "text": "",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "tag": "BRL",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRL",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRL",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRL",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRL",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRL",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRL",
#                             "text": "",
#                             "children": []
#                         }
#                     ]
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "HL4",
#                     "text": "UNIFIED FACILITIES GUIDE SPECIFICATIONS",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "AST",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 }
#             ]
#         },
#         {
#             "tag": "BRK",
#             "text": "",
#             "children": []
#         },
#         {
#             "tag": "SCN",
#             "text": "DOCUMENT 00 01 15",
#             "children": []
#         },
#         {
#             "tag": "BRK",
#             "text": "",
#             "children": []
#         },
#         {
#             "tag": "BRK",
#             "text": "",
#             "children": []
#         },
#         {
#             "tag": "STL",
#             "text": "LIST OF DRAWINGS",
#             "children": []
#         },
#         {
#             "tag": "BRK",
#             "text": "",
#             "children": []
#         },
#         {
#             "tag": "DTE",
#             "text": "02/24",
#             "children": []
#         },
#         {
#             "tag": "BRK",
#             "text": "",
#             "children": []
#         },
#         {
#             "tag": "NTE",
#             "text": "",
#             "children": [
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "AST",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "NPR",
#                     "text": "NOTE:  This guide specification covers the requirements for",
#                     "children": [
#                         {
#                             "tag": "SCP",
#                             "text": "list of drawings for the project",
#                             "children": []
#                         }
#                     ]
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "NPR",
#                     "text": "Adhere to",
#                     "children": [
#                         {
#                             "tag": "URL",
#                             "text": "UFC 1-300-02",
#                             "children": []
#                         }
#                     ]
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "NPR",
#                     "text": "Remove information and requirements not required in respective project, whether or not brackets are present.",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "NPR",
#                     "text": "Comments, suggestions and recommended changes for this guide specification are welcome and should be submitted \nas a",
#                     "children": [
#                         {
#                             "tag": "URL",
#                             "text": "Criteria Change Request (CCR)",
#                             "children": []
#                         }
#                     ]
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "AST",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 }
#             ]
#         },
#         {
#             "tag": "BRK",
#             "text": "",
#             "children": []
#         },
#         {
#             "tag": "PRT",
#             "text": "",
#             "children": [
#                 {
#                     "tag": "TTL",
#                     "text": "PART 1   GENERAL",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "BRK",
#                     "text": "",
#                     "children": []
#                 },
#                 {
#                     "tag": "SPT",
#                     "text": "",
#                     "children": [
#                         {
#                             "tag": "TTL",
#                             "text": "SUMMARY",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "TXT",
#                             "text": "This section lists the drawings for the project pursuant to contract clause \"DFARS 252.236-7001, Contract Drawings and Specifications.\"",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         }
#                     ]
#                 },
#                 {
#                     "tag": "SPT",
#                     "text": "",
#                     "children": [
#                         {
#                             "tag": "TTL",
#                             "text": "CONTRACT DRAWINGS",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "NTE",
#                             "text": "",
#                             "children": [
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "AST",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "NPR",
#                                     "text": "NOTE:  Use revision column only if drawings show a revision date.  NAVFAC projects must list the 7-digit NAVFAC \ndrawing number in the third column.",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "AST",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 }
#                             ]
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "TXT",
#                             "text": "Contract drawings are as follows:",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "TAB",
#                             "text": "",
#                             "children": [
#                                 {
#                                     "tag": "WBK",
#                                     "text": "",
#                                     "children": [
#                                         {
#                                             "tag": "STS",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "TDA",
#                                             "text": "",
#                                             "children": [
#                                                 {
#                                                     "tag": "COL",
#                                                     "text": "",
#                                                     "children": []
#                                                 },
#                                                 {
#                                                     "tag": "COL",
#                                                     "text": "",
#                                                     "children": []
#                                                 },
#                                                 {
#                                                     "tag": "COL",
#                                                     "text": "",
#                                                     "children": []
#                                                 },
#                                                 {
#                                                     "tag": "COL",
#                                                     "text": "",
#                                                     "children": []
#                                                 },
#                                                 {
#                                                     "tag": "ROW",
#                                                     "text": "",
#                                                     "children": [
#                                                         {
#                                                             "tag": "CEL",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "DTA",
#                                                                     "text": "DRAWING NO.",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         },
#                                                         {
#                                                             "tag": "CEL",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "DTA",
#                                                                     "text": "[REVISION NO.]",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         },
#                                                         {
#                                                             "tag": "CEL",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "DTA",
#                                                                     "text": "NAVFAC DWG NO.",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         },
#                                                         {
#                                                             "tag": "CEL",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "DTA",
#                                                                     "text": "TITLE",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "tag": "ROW",
#                                                     "text": "",
#                                                     "children": [
#                                                         {
#                                                             "tag": "CEL",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "DTA",
#                                                                     "text": "[_____]",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         },
#                                                         {
#                                                             "tag": "CEL",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "DTA",
#                                                                     "text": "[_____]",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         },
#                                                         {
#                                                             "tag": "CEL",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "DTA",
#                                                                     "text": "[_____]",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         },
#                                                         {
#                                                             "tag": "CEL",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "DTA",
#                                                                     "text": "[_____]",
#                                                                     "children": []
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "tag": "BRL",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRL",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRL",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRL",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRL",
#                                     "text": "",
#                                     "children": []
#                                 }
#                             ]
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         }
#                     ]
#                 },
#                 {
#                     "tag": "SPT",
#                     "text": "",
#                     "children": [
#                         {
#                             "tag": "TTL",
#                             "text": "SUPPLEMENTARY DRAWINGS",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "TXT",
#                             "text": "These supplementary drawings may not be a part of the contract but are included with the drawings for information.",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "BRK",
#                             "text": "",
#                             "children": []
#                         },
#                         {
#                             "tag": "SPT",
#                             "text": "",
#                             "children": [
#                                 {
#                                     "tag": "TTL",
#                                     "text": "Reference Drawing[s]",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "NTE",
#                                     "text": "",
#                                     "children": [
#                                         {
#                                             "tag": "BRK",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "AST",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRK",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "NPR",
#                                             "text": "NOTE:  Use only when reference drawings must be included in the project.",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRK",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "AST",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRK",
#                                             "text": "",
#                                             "children": []
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "TXT",
#                                     "text": "The following reference drawing[s] [is][are] intended only to show the original construction.  Drawing[s] [is][are] the property of the Government \nand shall not be used for any purpose other than that intended by the contract.[  The drawing[s] [is][are] [half-][full-]size.  Full-size drawings \nare available at the bidder's or Contractor's expense.[  Information on procuring these full-size drawings may be obtained from the Contracting \nOfficer.][  Full size drawings may be inspected during regular working hours at[ the office of the Contracting Officer.][ the station.]]",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "TAB",
#                                     "text": "",
#                                     "children": [
#                                         {
#                                             "tag": "WBK",
#                                             "text": "",
#                                             "children": [
#                                                 {
#                                                     "tag": "STS",
#                                                     "text": "",
#                                                     "children": []
#                                                 },
#                                                 {
#                                                     "tag": "TDA",
#                                                     "text": "",
#                                                     "children": [
#                                                         {
#                                                             "tag": "COL",
#                                                             "text": "",
#                                                             "children": []
#                                                         },
#                                                         {
#                                                             "tag": "COL",
#                                                             "text": "",
#                                                             "children": []
#                                                         },
#                                                         {
#                                                             "tag": "ROW",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "CEL",
#                                                                     "text": "",
#                                                                     "children": [
#                                                                         {
#                                                                             "tag": "DTA",
#                                                                             "text": "NAVFAC DWG NO.",
#                                                                             "children": []
#                                                                         }
#                                                                     ]
#                                                                 },
#                                                                 {
#                                                                     "tag": "CEL",
#                                                                     "text": "",
#                                                                     "children": [
#                                                                         {
#                                                                             "tag": "DTA",
#                                                                             "text": "TITLE",
#                                                                             "children": []
#                                                                         }
#                                                                     ]
#                                                                 }
#                                                             ]
#                                                         },
#                                                         {
#                                                             "tag": "ROW",
#                                                             "text": "",
#                                                             "children": [
#                                                                 {
#                                                                     "tag": "CEL",
#                                                                     "text": "",
#                                                                     "children": [
#                                                                         {
#                                                                             "tag": "DTA",
#                                                                             "text": "[_____]",
#                                                                             "children": []
#                                                                         }
#                                                                     ]
#                                                                 },
#                                                                 {
#                                                                     "tag": "CEL",
#                                                                     "text": "",
#                                                                     "children": [
#                                                                         {
#                                                                             "tag": "DTA",
#                                                                             "text": "[_____]",
#                                                                             "children": []
#                                                                         }
#                                                                     ]
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "text": "",
#                                             "children": []
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 }
#                             ]
#                         },
#                         {
#                             "tag": "SPT",
#                             "text": "",
#                             "children": [
#                                 {
#                                     "tag": "TTL",
#                                     "text": "Boring Logs",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "text": "",
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "NTE",
#                                     "text": "",
#                                     "children": [
#                                         {
#                                             "tag": "BRK",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "AST",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRK",
#                                             "text": "",
#                                             "children": []
#                                         },
#                                         {
# ...
#                                                                             "children": []
#                                                                         }
#                                                                     ]
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRL",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 }
#                             ]
#                         },
#                         {
#                             "tag": "SPT",
#                             "xml_text": "",
#                             "pdf_text": null,
#                             "page": null,
#                             "bbox": null,
#                             "normalized_bbox": null,
#                             "children": [
#                                 {
#                                     "tag": "TTL",
#                                     "xml_text": "Boring Logs",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "NTE",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": [
#                                         {
#                                             "tag": "BRK",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "AST",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRK",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "NPR",
#                                             "xml_text": "NOTE:  Select this paragraph BORING LOGS or paragraph SUBSURFACE DATA if the boring logs and subsurface information \nare not already incorporated in the drawings.  Use the first paragraph if boring logs are available and the second \nif they are incorporated into a soils report or if only a soils report is available.",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRK",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "AST",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         },
#                                         {
#                                             "tag": "BRK",
#                                             "xml_text": "",
#                                             "pdf_text": null,
#                                             "page": null,
#                                             "bbox": null,
#                                             "normalized_bbox": null,
#                                             "children": []
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "TXT",
#                                     "xml_text": "The Government does not guarantee that borings indicate actual conditions, except for the exact locations and the time that they were made.[  Subsurface \ndata, not specified or indicated, have been obtained by the Government at this station.  The data are available for examination by prospective \nbidders[ in the office of the Contracting Officer][ at the station].]",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 }
#                             ]
#                         },
#                         {
#                             "tag": "SPT",
#                             "xml_text": "",
#                             "pdf_text": null,
#                             "page": null,
#                             "bbox": null,
#                             "normalized_bbox": null,
#                             "children": [
#                                 {
#                                     "tag": "TTL",
#                                     "xml_text": "Subsurface Data",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "NED",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "TXT",
#                                     "xml_text": "Subsurface data, not specified or indicated, have been obtained by the Government at the station.  The data are available for examination by prospective \nbidders[ in the office of the Contracting Officer][ at the station].[  The soils report is included as part of the solicitation.]",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 },
#                                 {
#                                     "tag": "BRK",
#                                     "xml_text": "",
#                                     "pdf_text": null,
#                                     "page": null,
#                                     "bbox": null,
#                                     "normalized_bbox": null,
#                                     "children": []
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "tag": "EOD",
#             "xml_text": "",
#             "pdf_text": null,
#             "page": null,
#             "bbox": null,
#             "normalized_bbox": null,
#             "children": []
#         },
#         {
#             "tag": "BRK",
#             "xml_text": "",
#             "pdf_text": null,
#             "page": null,
#             "bbox": null,
#             "normalized_bbox": null,
#             "children": []
#         }
#     ]
# }
#
# ****** Saving Aligned Data
# --- Saving aligned data to: /content/aligned_data_with_pages.json
# --- Data saved successfully at: /content/aligned_data_with_pages.json
#
# ****** Summary
# Aligned XML-PDF data saved at: /content/aligned_data_with_pages.json

# %% [markdown]
# # Visualize extracted sections in PDF

# %%
# Install necessary libraries
# !pip install pymupdf

import fitz  # PyMuPDF
import json
import random

# Load the hierarchical JSON data
def load_hierarchical_json(json_path):
    print(f"Loading hierarchical JSON from: {json_path}")
    with open(json_path, "r") as f:
        data = json.load(f)
    print("JSON loaded successfully.")
    return data

# Generate a consistent color for each unique tag
def generate_color_map(tags):
    print("Generating color map for tags.")
    random.seed(42)  # Set seed for reproducibility
    color_map = {}
    for tag in tags:
        color_map[tag] = (
            random.randint(0, 255) / 255.0,  # Normalize to range [0, 1]
            random.randint(0, 255) / 255.0,  # Normalize to range [0, 1]
            random.randint(0, 255) / 255.0,  # Normalize to range [0, 1]
        )  # RGB colors
    print("Color map generated:", color_map)
    return color_map

# Recursive function to apply boxes and labels
def annotate_pdf_with_hierarchy(pdf_path, json_data, output_pdf_path):
    print(f"Opening PDF file: {pdf_path}")
    doc = fitz.open(pdf_path)
    print("PDF opened successfully.")

    # Gather all unique tags
    def collect_tags(data, tags):
        tags.add(data["tag"])
        for child in data.get("children", []):
            collect_tags(child, tags)

    unique_tags = set()
    collect_tags(json_data, unique_tags)

    # Generate color map for tags
    color_map = generate_color_map(unique_tags)

    def recursive_annotate(page, data, parent_tag=""):
        # Combine the current tag with the parent tag for a compound tag
        compound_tag = f"{parent_tag}/{data['tag']}" if parent_tag else data["tag"]

        # If the tag has children, process them recursively and skip drawing for parent tags
        if data.get("children", []):
            for child in data["children"]:
                recursive_annotate(page, child, compound_tag)
            return  # Only annotate the leaf nodes

        # Log current data being processed
        print(f"Processing Tag: {compound_tag}")
        print(f"Page: {data.get('page', 'Not Specified')}, BBox: {data.get('bbox', 'Not Specified')}")
        print(f"PDF Text: {data.get('pdf_text', 'Not Specified')}")

        # Draw a box and add a label if the item has a bounding box
        if data["bbox"] and data["pdf_text"]:
            bbox = fitz.Rect(data["bbox"])  # Convert to PyMuPDF Rect
            if not bbox.intersects(page.rect):  # Check if bbox is within page bounds
                print(f"Skipping invalid bounding box for tag {compound_tag}: {data['bbox']}")
                return

            color = color_map[data["tag"]]  # Get color for the current tag
            print(f"Drawing rectangle for tag {compound_tag} | BBox: {bbox} | Color: {color}")

            # Draw a rectangle around the bounding box
            try:
                page.draw_rect(
                    bbox,
                    color=color,
                    width=1,  # Thickness of the rectangle
                )
                print(f"Rectangle drawn for tag {compound_tag}")
            except Exception as e:
                print(f"Error drawing rectangle for tag {compound_tag}: {e}")

            # Add the compound tag as a label above the box
            try:
                # Position the label slightly above the bounding box
                label_position = fitz.Point(bbox.x0, bbox.y0 - 2)  # Place label above bbox
                print(f"Attempting to add label for tag {compound_tag} at position: {label_position}")

                # Debug: Print the text that will be added
                print(f"Text to be printed: '{compound_tag}'")

                # Insert the label text directly
                font_size = 3  # Font size set to 3pt
                text_color = (0, 0, 0)  # Black text
                font_name = "Helvetica"  # Use Helvetica font
                page.insert_text(
                    label_position,
                    compound_tag,
                    fontsize=font_size,
                    color=text_color,  # Black text
                    fontname=font_name,  # Explicit font specification
                )
                print(f"Label added for tag {compound_tag} at position {label_position}")
            except Exception as e:
                print(f"Error adding label for tag {compound_tag}: {e}")

    # Recursively annotate the root element (hierarchical JSON starts as a dict)
    def process_hierarchy(data):
        if "page" in data and isinstance(data["page"], int):
            page_number = data["page"]  # Get the page number
            print(f"Processing page {page_number}.")
            try:
                page = doc[page_number - 1]  # Pages are 0-indexed in PyMuPDF
                recursive_annotate(page, data)
            except IndexError:
                print(f"Page {page_number} does not exist in the PDF.")
        else:
            print(f"Skipping tag {data['tag']} with invalid or missing page number.")

        # Process children at the root level
        for child in data.get("children", []):
            process_hierarchy(child)

    # Start processing the root JSON
    print("Starting annotation process.")
    process_hierarchy(json_data)
    print("Annotation process completed.")

    # Save the annotated PDF
    print(f"Saving annotated PDF to: {output_pdf_path}")
    doc.save(output_pdf_path)
    doc.close()
    print("Annotated PDF saved successfully.")

# Main Execution
pdf_path = "/content/UFGS_00_01_15.pdf"  # Input PDF file
json_path = "/content/aligned_data_with_pages.json"  # Hierarchical JSON file
output_pdf_path = "/content/annotated_UFGS_00_01_15.pdf"  # Output annotated PDF file

# Load the hierarchical JSON data
hierarchical_json = load_hierarchical_json(json_path)

# Annotate the PDF using the hierarchical JSON
annotate_pdf_with_hierarchy(pdf_path, hierarchical_json, output_pdf_path)
# Out:
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.10/dist-packages (1.24.14)
# Loading hierarchical JSON from: /content/aligned_data_with_pages.json
# JSON loaded successfully.
# Opening PDF file: /content/UFGS_00_01_15.pdf
# PDF opened successfully.
# Generating color map for tags.
# Color map generated: {'BRL': (0.2235294117647059, 0.047058823529411764, 0.5490196078431373), 'DTE': (0.49019607843137253, 0.4470588235294118, 0.2784313725490196), 'NED': (0.20392156862745098, 0.17254901960784313, 0.8470588235294118), 'STS': (0.06274509803921569, 0.058823529411764705, 0.1843137254901961), 'SCN': (0.43529411764705883, 0.4666666666666667, 0.050980392156862744), 'DTA': (0.396078431372549, 0.8392156862745098, 0.4392156862745098), 'SCP': (0.8980392156862745, 0.5568627450980392, 0.011764705882352941), 'PRT': (0.3176470588235294, 0.8470588235294118, 0.6823529411764706), 'SPT': (0.5568627450980392, 0.30980392156862746, 0.43137254901960786), 'TDA': (0.6745098039215687, 0.20392156862745098, 0.1843137254901961), 'WBK': (0.7607843137254902, 0.19215686274509805, 0.7176470588235294), 'COL': (0.6901960784313725, 0.5294117647058824, 0.08627450980392157), 'TTL': (0.9215686274509803, 0.24705882352941178, 0.7568627450980392), 'NTE': (0.1568627450980392, 0.5882352941176471, 0.7254901960784313), 'STL': (0.3843137254901961, 0.13725490196078433, 0.09019607843137255), 'TXT': (0.4549019607843137, 0.5803921568627451, 0.1568627450980392), 'HDR': (0.4666666666666667, 0.2, 0.7607843137254902), 'TAB': (0.5568627450980392, 0.9098039215686274, 0.7294117647058823), 'PRA': (0.3254901960784314, 0.7411764705882353, 0.7098039215686275), 'NPR': (0.4196078431372549, 0.5333333333333333, 0.1411764705882353), 'ALN': (0.3411764705882353, 0.49019607843137253, 0.3254901960784314), 'AST': (0.9254901960784314, 0.7607843137254902, 0.5411764705882353), 'ROW': (0.4392156862745098, 0.6509803921568628, 0.10980392156862745), 'HL4': (0.4588235294117647, 0.06274509803921569, 0.6313725490196078), 'STY': (0.803921568627451, 0.5372549019607843, 0.12941176470588237), 'BRK': (0.4235294117647059, 0.6313725490196078, 0.4235294117647059), 'URL': (1.0, 0.792156862745098, 0.9176470588235294), 'EOD': (0.28627450980392155, 0.5294117647058824, 0.2784313725490196), 'SEC': (0.49411764705882355, 0.5254901960784314, 0.8588235294117647), 'CEL': (0.8, 0.7254901960784313, 0.4392156862745098), 'MTA': (0.27450980392156865, 0.9882352941176471, 0.1803921568627451), 'HL3': (0.09411764705882353, 0.2196078431372549, 0.3058823529411765)}
# Starting annotation process.
# Skipping tag SEC with invalid or missing page number.
# Processing page 1.
# Processing Tag: MTA
# Page: 1, BBox: [81.0, 69.97003936767578, 525.0, 83.97003936767578]
# PDF Text: **************************************************************************
# Drawing rectangle for tag MTA | BBox: Rect(81.0, 69.97003936767578, 525.0, 83.97003936767578) | Color: (0.27450980392156865, 0.9882352941176471, 0.1803921568627451)
# Rectangle drawn for tag MTA
# Attempting to add label for tag MTA at position: Point(81.0, 67.97003936767578)
# Text to be printed: 'MTA'
# Label added for tag MTA at position Point(81.0, 67.97003936767578)
# Processing page 1.
# Processing Tag: MTA
# Page: 1, BBox: [81.83808135986328, 81.7746810913086, 428.0167541503906, 93.87068176269531]
# PDF Text: USACE / NAVFAC / AFCEC
# 00 01 15 (February 2024)
# Drawing rectangle for tag MTA | BBox: Rect(81.83808135986328, 81.7746810913086, 428.0167541503906, 93.87068176269531) | Color: (0.27450980392156865, 0.9882352941176471, 0.1803921568627451)
# Rectangle drawn for tag MTA
# Attempting to add label for tag MTA at position: Point(81.83808135986328, 79.7746810913086)
# Text to be printed: 'MTA'
# Label added for tag MTA at position Point(81.83808135986328, 79.7746810913086)
# Processing page 3.
# Processing Tag: HDR/AST
# Page: 1, BBox: [303.6009826660156, 107.6947250366211, 490.2246398925781, 119.79072570800781]
# PDF Text: ------------------------------------
# Drawing rectangle for tag HDR/AST | BBox: Rect(303.6009826660156, 107.6947250366211, 490.2246398925781, 119.79072570800781) | Color: (0.9254901960784314, 0.7607843137254902, 0.5411764705882353)
# Rectangle drawn for tag HDR/AST
# Attempting to add label for tag HDR/AST at position: Point(303.6009826660156, 105.6947250366211)
# Text to be printed: 'HDR/AST'
# Label added for tag HDR/AST at position Point(303.6009826660156, 105.6947250366211)
# Processing Tag: HDR/TAB/WBK/STS/STY/ALN
# Page: 1, BBox: [81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328]
# PDF Text: Preparing Activity:  NAVFAC
# Superseding
# UFGS-00 01 15 (February 2011)
# Drawing rectangle for tag HDR/TAB/WBK/STS/STY/ALN | BBox: Rect(81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328) | Color: (0.3411764705882353, 0.49019607843137253, 0.3254901960784314)
# Rectangle drawn for tag HDR/TAB/WBK/STS/STY/ALN
# Attempting to add label for tag HDR/TAB/WBK/STS/STY/ALN at position: Point(81.83808135986328, 117.2204818725586)
# Text to be printed: 'HDR/TAB/WBK/STS/STY/ALN'
# Label added for tag HDR/TAB/WBK/STS/STY/ALN at position Point(81.83808135986328, 117.2204818725586)
# Processing Tag: HDR/TAB/WBK/TDA/COL
# Page: 1, BBox: [230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578]
# PDF Text: SECTION TABLE OF CONTENTS
# Drawing rectangle for tag HDR/TAB/WBK/TDA/COL | BBox: Rect(230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/COL
# Attempting to add label for tag HDR/TAB/WBK/TDA/COL at position: Point(230.0399932861328, 214.51995849609375)
# Text to be printed: 'HDR/TAB/WBK/TDA/COL'
# Label added for tag HDR/TAB/WBK/TDA/COL at position Point(230.0399932861328, 214.51995849609375)
# Processing Tag: HDR/TAB/WBK/TDA/COL
# Page: 1, BBox: [143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703]
# PDF Text: DIVISION 00 - PROCUREMENT AND CONTRACTING REQUIREMENTS
# Drawing rectangle for tag HDR/TAB/WBK/TDA/COL | BBox: Rect(143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/COL
# Attempting to add label for tag HDR/TAB/WBK/TDA/COL at position: Point(143.0399932861328, 236.48004150390625)
# Text to be printed: 'HDR/TAB/WBK/TDA/COL'
# Label added for tag HDR/TAB/WBK/TDA/COL at position Point(143.0399932861328, 236.48004150390625)
# Processing Tag: HDR/TAB/WBK/TDA/ROW/CEL/DTA
# Page: 1, BBox: [254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594]
# PDF Text: DOCUMENT 00 01 15
# Drawing rectangle for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA | BBox: Rect(254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA
# Attempting to add label for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA at position: Point(254.0399932861328, 258.44000244140625)
# Text to be printed: 'HDR/TAB/WBK/TDA/ROW/CEL/DTA'
# Label added for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA at position Point(254.0399932861328, 258.44000244140625)
# Processing Tag: HDR/TAB/WBK/TDA/ROW/CEL/DTA
# Page: 1, BBox: [290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125]
# PDF Text: 02/24
# Drawing rectangle for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA | BBox: Rect(290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA
# Attempting to add label for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA at position: Point(290.0400085449219, 301.969970703125)
# Text to be printed: 'HDR/TAB/WBK/TDA/ROW/CEL/DTA'
# Label added for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA at position Point(290.0400085449219, 301.969970703125)
# Processing Tag: HDR/TAB/WBK/TDA/ROW/CEL
# Page: 1, BBox: [83.04000091552734, 436.4800109863281, 311.0400085449219, 448.97003173828125]
# PDF Text: -- End of Section Table of Contents --
# Drawing rectangle for tag HDR/TAB/WBK/TDA/ROW/CEL | BBox: Rect(83.04000091552734, 436.4800109863281, 311.0400085449219, 448.97003173828125) | Color: (0.8, 0.7254901960784313, 0.4392156862745098)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/ROW/CEL
# Attempting to add label for tag HDR/TAB/WBK/TDA/ROW/CEL at position: Point(83.04000091552734, 434.4800109863281)
# Text to be printed: 'HDR/TAB/WBK/TDA/ROW/CEL'
# Label added for tag HDR/TAB/WBK/TDA/ROW/CEL at position Point(83.04000091552734, 434.4800109863281)
# Processing Tag: HDR/TAB/WBK/TDA/ROW/CEL
# Page: 1, BBox: [230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125]
# PDF Text: DOCUMENT 00 01 15  Page 1
# Drawing rectangle for tag HDR/TAB/WBK/TDA/ROW/CEL | BBox: Rect(230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125) | Color: (0.8, 0.7254901960784313, 0.4392156862745098)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/ROW/CEL
# Attempting to add label for tag HDR/TAB/WBK/TDA/ROW/CEL at position: Point(230.0399932861328, 737.47998046875)
# Text to be printed: 'HDR/TAB/WBK/TDA/ROW/CEL'
# Label added for tag HDR/TAB/WBK/TDA/ROW/CEL at position Point(230.0399932861328, 737.47998046875)
# Processing Tag: HDR/TAB/WBK/TDA/ROW/CEL/DTA/HL3
# Page: 2, BBox: [81.83808135986328, 93.3004379272461, 428.0167541503906, 105.39643859863281]
# PDF Text: USACE / NAVFAC / AFCEC
# 00 01 15 (February 2024)
# Drawing rectangle for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/HL3 | BBox: Rect(81.83808135986328, 93.3004379272461, 428.0167541503906, 105.39643859863281) | Color: (0.09411764705882353, 0.2196078431372549, 0.3058823529411765)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/HL3
# Attempting to add label for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/HL3 at position: Point(81.83808135986328, 91.3004379272461)
# Text to be printed: 'HDR/TAB/WBK/TDA/ROW/CEL/DTA/HL3'
# Label added for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/HL3 at position Point(81.83808135986328, 91.3004379272461)
# Processing Tag: HDR/TAB/WBK/TDA/ROW/CEL/DTA/PRA
# Page: 2, BBox: [81.0, 195.00994873046875, 525.0, 209.00994873046875]
# PDF Text: **************************************************************************
# Drawing rectangle for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/PRA | BBox: Rect(81.0, 195.00994873046875, 525.0, 209.00994873046875) | Color: (0.3254901960784314, 0.7411764705882353, 0.7098039215686275)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/PRA
# Attempting to add label for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/PRA at position: Point(81.0, 193.00994873046875)
# Text to be printed: 'HDR/TAB/WBK/TDA/ROW/CEL/DTA/PRA'
# Label added for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/PRA at position Point(81.0, 193.00994873046875)
# Processing Tag: HDR/TAB/WBK/TDA/ROW/CEL/DTA/BRK
# Page: 2, BBox: [290.0400085449219, 249.97003173828125, 320.0400085449219, 263.97003173828125]
# PDF Text: 02/24
# Drawing rectangle for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/BRK | BBox: Rect(290.0400085449219, 249.97003173828125, 320.0400085449219, 263.97003173828125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/BRK
# Attempting to add label for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/BRK at position: Point(290.0400085449219, 247.97003173828125)
# Text to be printed: 'HDR/TAB/WBK/TDA/ROW/CEL/DTA/BRK'
# Label added for tag HDR/TAB/WBK/TDA/ROW/CEL/DTA/BRK at position Point(290.0400085449219, 247.97003173828125)
# Processing Tag: HDR/TAB/BRL
# Page: 2, BBox: [81.0, 492.0099792480469, 525.0, 506.0099792480469]
# PDF Text: **************************************************************************
# Drawing rectangle for tag HDR/TAB/BRL | BBox: Rect(81.0, 492.0099792480469, 525.0, 506.0099792480469) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag HDR/TAB/BRL
# Attempting to add label for tag HDR/TAB/BRL at position: Point(81.0, 490.0099792480469)
# Text to be printed: 'HDR/TAB/BRL'
# Label added for tag HDR/TAB/BRL at position Point(81.0, 490.0099792480469)
# Processing Tag: HDR/TAB/BRL
# Page: 2, BBox: [72.0, 514.47998046875, 168.0, 526.969970703125]
# PDF Text: PART 1   GENERAL
# Drawing rectangle for tag HDR/TAB/BRL | BBox: Rect(72.0, 514.47998046875, 168.0, 526.969970703125) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag HDR/TAB/BRL
# Attempting to add label for tag HDR/TAB/BRL at position: Point(72.0, 512.47998046875)
# Text to be printed: 'HDR/TAB/BRL'
# Label added for tag HDR/TAB/BRL at position Point(72.0, 512.47998046875)
# Processing Tag: HDR/TAB/BRL
# Page: 2, BBox: [72.0, 536.4400024414062, 150.0, 548.9299926757812]
# PDF Text: 1.1   SUMMARY
# Drawing rectangle for tag HDR/TAB/BRL | BBox: Rect(72.0, 536.4400024414062, 150.0, 548.9299926757812) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag HDR/TAB/BRL
# Attempting to add label for tag HDR/TAB/BRL at position: Point(72.0, 534.4400024414062)
# Text to be printed: 'HDR/TAB/BRL'
# Label added for tag HDR/TAB/BRL at position Point(72.0, 534.4400024414062)
# Processing Tag: HDR/TAB/BRL
# Page: 2, BBox: [83.04000091552734, 558.5199584960938, 497.0400085449219, 581.9299926757812]
# PDF Text: This section lists the drawings for the project pursuant to contract
# clause "DFARS 252.236-7001, Contract Drawings and Specifications."
# Drawing rectangle for tag HDR/TAB/BRL | BBox: Rect(83.04000091552734, 558.5199584960938, 497.0400085449219, 581.9299926757812) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag HDR/TAB/BRL
# Attempting to add label for tag HDR/TAB/BRL at position: Point(83.04000091552734, 556.5199584960938)
# Text to be printed: 'HDR/TAB/BRL'
# Label added for tag HDR/TAB/BRL at position Point(83.04000091552734, 556.5199584960938)
# Processing Tag: HDR/TAB/BRL
# Page: 2, BBox: [72.0, 591.52001953125, 210.0, 604.010009765625]
# PDF Text: 1.2   CONTRACT DRAWINGS
# Drawing rectangle for tag HDR/TAB/BRL | BBox: Rect(72.0, 591.52001953125, 210.0, 604.010009765625) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag HDR/TAB/BRL
# Attempting to add label for tag HDR/TAB/BRL at position: Point(72.0, 589.52001953125)
# Text to be printed: 'HDR/TAB/BRL'
# Label added for tag HDR/TAB/BRL at position Point(72.0, 589.52001953125)
# Processing Tag: HDR/TAB/BRL
# Page: 2, BBox: [81.0, 612.9700317382812, 525.0, 626.9700317382812]
# PDF Text: **************************************************************************
# Drawing rectangle for tag HDR/TAB/BRL | BBox: Rect(81.0, 612.9700317382812, 525.0, 626.9700317382812) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag HDR/TAB/BRL
# Attempting to add label for tag HDR/TAB/BRL at position: Point(81.0, 610.9700317382812)
# Text to be printed: 'HDR/TAB/BRL'
# Label added for tag HDR/TAB/BRL at position Point(81.0, 610.9700317382812)
# Processing Tag: HDR/TAB/BRL
# Page: 2, BBox: [144.9600067138672, 624.010009765625, 450.96002197265625, 659.9700317382812]
# PDF Text: NOTE:  Use revision column only if drawings show a
# revision date.  NAVFAC projects must list the
# 7-digit NAVFAC drawing number in the third column.
# Drawing rectangle for tag HDR/TAB/BRL | BBox: Rect(144.9600067138672, 624.010009765625, 450.96002197265625, 659.9700317382812) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag HDR/TAB/BRL
# Attempting to add label for tag HDR/TAB/BRL at position: Point(144.9600067138672, 622.010009765625)
# Text to be printed: 'HDR/TAB/BRL'
# Label added for tag HDR/TAB/BRL at position Point(144.9600067138672, 622.010009765625)
# Processing Tag: HDR/BRK
# Page: 2, BBox: [83.04000091552734, 679.47998046875, 281.0400085449219, 691.969970703125]
# PDF Text: Contract drawings are as follows:
# Drawing rectangle for tag HDR/BRK | BBox: Rect(83.04000091552734, 679.47998046875, 281.0400085449219, 691.969970703125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag HDR/BRK
# Attempting to add label for tag HDR/BRK at position: Point(83.04000091552734, 677.47998046875)
# Text to be printed: 'HDR/BRK'
# Label added for tag HDR/BRK at position Point(83.04000091552734, 677.47998046875)
# Processing Tag: HDR/HL4
# Page: 2, BBox: [230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125]
# PDF Text: DOCUMENT 00 01 15  Page 2
# Drawing rectangle for tag HDR/HL4 | BBox: Rect(230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125) | Color: (0.4588235294117647, 0.06274509803921569, 0.6313725490196078)
# Rectangle drawn for tag HDR/HL4
# Attempting to add label for tag HDR/HL4 at position: Point(230.0399932861328, 737.47998046875)
# Text to be printed: 'HDR/HL4'
# Label added for tag HDR/HL4 at position Point(230.0399932861328, 737.47998046875)
# Processing Tag: HDR/BRK
# Page: 3, BBox: [73.91520690917969, 71.26844024658203, 350.3951721191406, 82.05979919433594]
# PDF Text: DRAWING NO.
# [REVISION NO.]
# NAVFAC DWG NO.
# TITLE
# Drawing rectangle for tag HDR/BRK | BBox: Rect(73.91520690917969, 71.26844024658203, 350.3951721191406, 82.05979919433594) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag HDR/BRK
# Attempting to add label for tag HDR/BRK at position: Point(73.91520690917969, 69.26844024658203)
# Text to be printed: 'HDR/BRK'
# Label added for tag HDR/BRK at position Point(73.91520690917969, 69.26844024658203)
# Processing Tag: HDR/BRK
# Page: 3, BBox: [73.91520690917969, 92.86847686767578, 360.7631530761719, 103.65983581542969]
# PDF Text: [_____]
# [_____]
# [_____]
# [_____]
# Drawing rectangle for tag HDR/BRK | BBox: Rect(73.91520690917969, 92.86847686767578, 360.7631530761719, 103.65983581542969) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag HDR/BRK
# Attempting to add label for tag HDR/BRK at position: Point(73.91520690917969, 90.86847686767578)
# Text to be printed: 'HDR/BRK'
# Label added for tag HDR/BRK at position Point(73.91520690917969, 90.86847686767578)
# Processing Tag: HDR/AST
# Page: 3, BBox: [72.0, 116.44001007080078, 246.0, 128.9300079345703]
# PDF Text: [1.3   SUPPLEMENTARY DRAWINGS
# Drawing rectangle for tag HDR/AST | BBox: Rect(72.0, 116.44001007080078, 246.0, 128.9300079345703) | Color: (0.9254901960784314, 0.7607843137254902, 0.5411764705882353)
# Rectangle drawn for tag HDR/AST
# Attempting to add label for tag HDR/AST at position: Point(72.0, 114.44001007080078)
# Text to be printed: 'HDR/AST'
# Label added for tag HDR/AST at position Point(72.0, 114.44001007080078)
# Processing Tag: HDR/BRK
# Page: 3, BBox: [83.04000091552734, 138.51995849609375, 509.0400085449219, 161.9300079345703]
# PDF Text: These supplementary drawings may not be a part of the contract but are
# included with the drawings for information.
# Drawing rectangle for tag HDR/BRK | BBox: Rect(83.04000091552734, 138.51995849609375, 509.0400085449219, 161.9300079345703) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag HDR/BRK
# Attempting to add label for tag HDR/BRK at position: Point(83.04000091552734, 136.51995849609375)
# Text to be printed: 'HDR/BRK'
# Label added for tag HDR/BRK at position Point(83.04000091552734, 136.51995849609375)
# Processing page 1.
# Processing Tag: AST
# Page: 1, BBox: [303.6009826660156, 107.6947250366211, 490.2246398925781, 119.79072570800781]
# PDF Text: ------------------------------------
# Drawing rectangle for tag AST | BBox: Rect(303.6009826660156, 107.6947250366211, 490.2246398925781, 119.79072570800781) | Color: (0.9254901960784314, 0.7607843137254902, 0.5411764705882353)
# Rectangle drawn for tag AST
# Attempting to add label for tag AST at position: Point(303.6009826660156, 105.6947250366211)
# Text to be printed: 'AST'
# Label added for tag AST at position Point(303.6009826660156, 105.6947250366211)
# Processing page 2.
# Processing Tag: TAB/WBK/STS/STY/ALN
# Page: 1, BBox: [81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328]
# PDF Text: Preparing Activity:  NAVFAC
# Superseding
# UFGS-00 01 15 (February 2011)
# Drawing rectangle for tag TAB/WBK/STS/STY/ALN | BBox: Rect(81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328) | Color: (0.3411764705882353, 0.49019607843137253, 0.3254901960784314)
# Rectangle drawn for tag TAB/WBK/STS/STY/ALN
# Attempting to add label for tag TAB/WBK/STS/STY/ALN at position: Point(81.83808135986328, 117.2204818725586)
# Text to be printed: 'TAB/WBK/STS/STY/ALN'
# Label added for tag TAB/WBK/STS/STY/ALN at position Point(81.83808135986328, 117.2204818725586)
# Processing Tag: TAB/WBK/TDA/COL
# Page: 1, BBox: [230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578]
# PDF Text: SECTION TABLE OF CONTENTS
# Drawing rectangle for tag TAB/WBK/TDA/COL | BBox: Rect(230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag TAB/WBK/TDA/COL
# Attempting to add label for tag TAB/WBK/TDA/COL at position: Point(230.0399932861328, 214.51995849609375)
# Text to be printed: 'TAB/WBK/TDA/COL'
# Label added for tag TAB/WBK/TDA/COL at position Point(230.0399932861328, 214.51995849609375)
# Processing Tag: TAB/WBK/TDA/COL
# Page: 1, BBox: [143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703]
# PDF Text: DIVISION 00 - PROCUREMENT AND CONTRACTING REQUIREMENTS
# Drawing rectangle for tag TAB/WBK/TDA/COL | BBox: Rect(143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag TAB/WBK/TDA/COL
# Attempting to add label for tag TAB/WBK/TDA/COL at position: Point(143.0399932861328, 236.48004150390625)
# Text to be printed: 'TAB/WBK/TDA/COL'
# Label added for tag TAB/WBK/TDA/COL at position Point(143.0399932861328, 236.48004150390625)
# Processing Tag: TAB/WBK/TDA/ROW/CEL/DTA
# Page: 1, BBox: [254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594]
# PDF Text: DOCUMENT 00 01 15
# Drawing rectangle for tag TAB/WBK/TDA/ROW/CEL/DTA | BBox: Rect(254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag TAB/WBK/TDA/ROW/CEL/DTA
# Attempting to add label for tag TAB/WBK/TDA/ROW/CEL/DTA at position: Point(254.0399932861328, 258.44000244140625)
# Text to be printed: 'TAB/WBK/TDA/ROW/CEL/DTA'
# Label added for tag TAB/WBK/TDA/ROW/CEL/DTA at position Point(254.0399932861328, 258.44000244140625)
# Processing Tag: TAB/WBK/TDA/ROW/CEL/DTA
# Page: 1, BBox: [290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125]
# PDF Text: 02/24
# Drawing rectangle for tag TAB/WBK/TDA/ROW/CEL/DTA | BBox: Rect(290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag TAB/WBK/TDA/ROW/CEL/DTA
# Attempting to add label for tag TAB/WBK/TDA/ROW/CEL/DTA at position: Point(290.0400085449219, 301.969970703125)
# Text to be printed: 'TAB/WBK/TDA/ROW/CEL/DTA'
# Label added for tag TAB/WBK/TDA/ROW/CEL/DTA at position Point(290.0400085449219, 301.969970703125)
# Processing Tag: TAB/WBK/TDA/ROW/CEL
# Page: 1, BBox: [83.04000091552734, 436.4800109863281, 311.0400085449219, 448.97003173828125]
# PDF Text: -- End of Section Table of Contents --
# Drawing rectangle for tag TAB/WBK/TDA/ROW/CEL | BBox: Rect(83.04000091552734, 436.4800109863281, 311.0400085449219, 448.97003173828125) | Color: (0.8, 0.7254901960784313, 0.4392156862745098)
# Rectangle drawn for tag TAB/WBK/TDA/ROW/CEL
# Attempting to add label for tag TAB/WBK/TDA/ROW/CEL at position: Point(83.04000091552734, 434.4800109863281)
# Text to be printed: 'TAB/WBK/TDA/ROW/CEL'
# Label added for tag TAB/WBK/TDA/ROW/CEL at position Point(83.04000091552734, 434.4800109863281)
# Processing Tag: TAB/WBK/TDA/ROW/CEL
# Page: 1, BBox: [230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125]
# PDF Text: DOCUMENT 00 01 15  Page 1
# Drawing rectangle for tag TAB/WBK/TDA/ROW/CEL | BBox: Rect(230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125) | Color: (0.8, 0.7254901960784313, 0.4392156862745098)
# Rectangle drawn for tag TAB/WBK/TDA/ROW/CEL
# Attempting to add label for tag TAB/WBK/TDA/ROW/CEL at position: Point(230.0399932861328, 737.47998046875)
# Text to be printed: 'TAB/WBK/TDA/ROW/CEL'
# Label added for tag TAB/WBK/TDA/ROW/CEL at position Point(230.0399932861328, 737.47998046875)
# Processing Tag: TAB/WBK/TDA/ROW/CEL/DTA/HL3
# Page: 2, BBox: [81.83808135986328, 93.3004379272461, 428.0167541503906, 105.39643859863281]
# PDF Text: USACE / NAVFAC / AFCEC
# 00 01 15 (February 2024)
# Drawing rectangle for tag TAB/WBK/TDA/ROW/CEL/DTA/HL3 | BBox: Rect(81.83808135986328, 93.3004379272461, 428.0167541503906, 105.39643859863281) | Color: (0.09411764705882353, 0.2196078431372549, 0.3058823529411765)
# Rectangle drawn for tag TAB/WBK/TDA/ROW/CEL/DTA/HL3
# Attempting to add label for tag TAB/WBK/TDA/ROW/CEL/DTA/HL3 at position: Point(81.83808135986328, 91.3004379272461)
# Text to be printed: 'TAB/WBK/TDA/ROW/CEL/DTA/HL3'
# Label added for tag TAB/WBK/TDA/ROW/CEL/DTA/HL3 at position Point(81.83808135986328, 91.3004379272461)
# Processing Tag: TAB/WBK/TDA/ROW/CEL/DTA/PRA
# Page: 2, BBox: [81.0, 195.00994873046875, 525.0, 209.00994873046875]
# PDF Text: **************************************************************************
# Drawing rectangle for tag TAB/WBK/TDA/ROW/CEL/DTA/PRA | BBox: Rect(81.0, 195.00994873046875, 525.0, 209.00994873046875) | Color: (0.3254901960784314, 0.7411764705882353, 0.7098039215686275)
# Rectangle drawn for tag TAB/WBK/TDA/ROW/CEL/DTA/PRA
# Attempting to add label for tag TAB/WBK/TDA/ROW/CEL/DTA/PRA at position: Point(81.0, 193.00994873046875)
# Text to be printed: 'TAB/WBK/TDA/ROW/CEL/DTA/PRA'
# Label added for tag TAB/WBK/TDA/ROW/CEL/DTA/PRA at position Point(81.0, 193.00994873046875)
# Processing Tag: TAB/WBK/TDA/ROW/CEL/DTA/BRK
# Page: 2, BBox: [290.0400085449219, 249.97003173828125, 320.0400085449219, 263.97003173828125]
# PDF Text: 02/24
# Drawing rectangle for tag TAB/WBK/TDA/ROW/CEL/DTA/BRK | BBox: Rect(290.0400085449219, 249.97003173828125, 320.0400085449219, 263.97003173828125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag TAB/WBK/TDA/ROW/CEL/DTA/BRK
# Attempting to add label for tag TAB/WBK/TDA/ROW/CEL/DTA/BRK at position: Point(290.0400085449219, 247.97003173828125)
# Text to be printed: 'TAB/WBK/TDA/ROW/CEL/DTA/BRK'
# Label added for tag TAB/WBK/TDA/ROW/CEL/DTA/BRK at position Point(290.0400085449219, 247.97003173828125)
# Processing Tag: TAB/BRL
# Page: 2, BBox: [81.0, 492.0099792480469, 525.0, 506.0099792480469]
# PDF Text: **************************************************************************
# Drawing rectangle for tag TAB/BRL | BBox: Rect(81.0, 492.0099792480469, 525.0, 506.0099792480469) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag TAB/BRL
# Attempting to add label for tag TAB/BRL at position: Point(81.0, 490.0099792480469)
# Text to be printed: 'TAB/BRL'
# Label added for tag TAB/BRL at position Point(81.0, 490.0099792480469)
# Processing Tag: TAB/BRL
# Page: 2, BBox: [72.0, 514.47998046875, 168.0, 526.969970703125]
# PDF Text: PART 1   GENERAL
# Drawing rectangle for tag TAB/BRL | BBox: Rect(72.0, 514.47998046875, 168.0, 526.969970703125) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag TAB/BRL
# Attempting to add label for tag TAB/BRL at position: Point(72.0, 512.47998046875)
# Text to be printed: 'TAB/BRL'
# Label added for tag TAB/BRL at position Point(72.0, 512.47998046875)
# Processing Tag: TAB/BRL
# Page: 2, BBox: [72.0, 536.4400024414062, 150.0, 548.9299926757812]
# PDF Text: 1.1   SUMMARY
# Drawing rectangle for tag TAB/BRL | BBox: Rect(72.0, 536.4400024414062, 150.0, 548.9299926757812) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag TAB/BRL
# Attempting to add label for tag TAB/BRL at position: Point(72.0, 534.4400024414062)
# Text to be printed: 'TAB/BRL'
# Label added for tag TAB/BRL at position Point(72.0, 534.4400024414062)
# Processing Tag: TAB/BRL
# Page: 2, BBox: [83.04000091552734, 558.5199584960938, 497.0400085449219, 581.9299926757812]
# PDF Text: This section lists the drawings for the project pursuant to contract
# clause "DFARS 252.236-7001, Contract Drawings and Specifications."
# Drawing rectangle for tag TAB/BRL | BBox: Rect(83.04000091552734, 558.5199584960938, 497.0400085449219, 581.9299926757812) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag TAB/BRL
# Attempting to add label for tag TAB/BRL at position: Point(83.04000091552734, 556.5199584960938)
# Text to be printed: 'TAB/BRL'
# Label added for tag TAB/BRL at position Point(83.04000091552734, 556.5199584960938)
# Processing Tag: TAB/BRL
# Page: 2, BBox: [72.0, 591.52001953125, 210.0, 604.010009765625]
# PDF Text: 1.2   CONTRACT DRAWINGS
# Drawing rectangle for tag TAB/BRL | BBox: Rect(72.0, 591.52001953125, 210.0, 604.010009765625) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag TAB/BRL
# Attempting to add label for tag TAB/BRL at position: Point(72.0, 589.52001953125)
# Text to be printed: 'TAB/BRL'
# Label added for tag TAB/BRL at position Point(72.0, 589.52001953125)
# Processing Tag: TAB/BRL
# Page: 2, BBox: [81.0, 612.9700317382812, 525.0, 626.9700317382812]
# PDF Text: **************************************************************************
# Drawing rectangle for tag TAB/BRL | BBox: Rect(81.0, 612.9700317382812, 525.0, 626.9700317382812) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag TAB/BRL
# Attempting to add label for tag TAB/BRL at position: Point(81.0, 610.9700317382812)
# Text to be printed: 'TAB/BRL'
# Label added for tag TAB/BRL at position Point(81.0, 610.9700317382812)
# Processing Tag: TAB/BRL
# Page: 2, BBox: [144.9600067138672, 624.010009765625, 450.96002197265625, 659.9700317382812]
# PDF Text: NOTE:  Use revision column only if drawings show a
# revision date.  NAVFAC projects must list the
# 7-digit NAVFAC drawing number in the third column.
# Drawing rectangle for tag TAB/BRL | BBox: Rect(144.9600067138672, 624.010009765625, 450.96002197265625, 659.9700317382812) | Color: (0.2235294117647059, 0.047058823529411764, 0.5490196078431373)
# Rectangle drawn for tag TAB/BRL
# Attempting to add label for tag TAB/BRL at position: Point(144.9600067138672, 622.010009765625)
# Text to be printed: 'TAB/BRL'
# Label added for tag TAB/BRL at position Point(144.9600067138672, 622.010009765625)
# Processing page 2.
# Processing Tag: WBK/STS/STY/ALN
# Page: 1, BBox: [81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328]
# PDF Text: Preparing Activity:  NAVFAC
# Superseding
# UFGS-00 01 15 (February 2011)
# Drawing rectangle for tag WBK/STS/STY/ALN | BBox: Rect(81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328) | Color: (0.3411764705882353, 0.49019607843137253, 0.3254901960784314)
# Rectangle drawn for tag WBK/STS/STY/ALN
# Attempting to add label for tag WBK/STS/STY/ALN at position: Point(81.83808135986328, 117.2204818725586)
# Text to be printed: 'WBK/STS/STY/ALN'
# Label added for tag WBK/STS/STY/ALN at position Point(81.83808135986328, 117.2204818725586)
# Processing Tag: WBK/TDA/COL
# Page: 1, BBox: [230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578]
# PDF Text: SECTION TABLE OF CONTENTS
# Drawing rectangle for tag WBK/TDA/COL | BBox: Rect(230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag WBK/TDA/COL
# Attempting to add label for tag WBK/TDA/COL at position: Point(230.0399932861328, 214.51995849609375)
# Text to be printed: 'WBK/TDA/COL'
# Label added for tag WBK/TDA/COL at position Point(230.0399932861328, 214.51995849609375)
# Processing Tag: WBK/TDA/COL
# Page: 1, BBox: [143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703]
# PDF Text: DIVISION 00 - PROCUREMENT AND CONTRACTING REQUIREMENTS
# Drawing rectangle for tag WBK/TDA/COL | BBox: Rect(143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag WBK/TDA/COL
# Attempting to add label for tag WBK/TDA/COL at position: Point(143.0399932861328, 236.48004150390625)
# Text to be printed: 'WBK/TDA/COL'
# Label added for tag WBK/TDA/COL at position Point(143.0399932861328, 236.48004150390625)
# Processing Tag: WBK/TDA/ROW/CEL/DTA
# Page: 1, BBox: [254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594]
# PDF Text: DOCUMENT 00 01 15
# Drawing rectangle for tag WBK/TDA/ROW/CEL/DTA | BBox: Rect(254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag WBK/TDA/ROW/CEL/DTA
# Attempting to add label for tag WBK/TDA/ROW/CEL/DTA at position: Point(254.0399932861328, 258.44000244140625)
# Text to be printed: 'WBK/TDA/ROW/CEL/DTA'
# Label added for tag WBK/TDA/ROW/CEL/DTA at position Point(254.0399932861328, 258.44000244140625)
# Processing Tag: WBK/TDA/ROW/CEL/DTA
# Page: 1, BBox: [290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125]
# PDF Text: 02/24
# Drawing rectangle for tag WBK/TDA/ROW/CEL/DTA | BBox: Rect(290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag WBK/TDA/ROW/CEL/DTA
# Attempting to add label for tag WBK/TDA/ROW/CEL/DTA at position: Point(290.0400085449219, 301.969970703125)
# Text to be printed: 'WBK/TDA/ROW/CEL/DTA'
# Label added for tag WBK/TDA/ROW/CEL/DTA at position Point(290.0400085449219, 301.969970703125)
# Processing Tag: WBK/TDA/ROW/CEL
# Page: 1, BBox: [83.04000091552734, 436.4800109863281, 311.0400085449219, 448.97003173828125]
# PDF Text: -- End of Section Table of Contents --
# Drawing rectangle for tag WBK/TDA/ROW/CEL | BBox: Rect(83.04000091552734, 436.4800109863281, 311.0400085449219, 448.97003173828125) | Color: (0.8, 0.7254901960784313, 0.4392156862745098)
# Rectangle drawn for tag WBK/TDA/ROW/CEL
# Attempting to add label for tag WBK/TDA/ROW/CEL at position: Point(83.04000091552734, 434.4800109863281)
# Text to be printed: 'WBK/TDA/ROW/CEL'
# Label added for tag WBK/TDA/ROW/CEL at position Point(83.04000091552734, 434.4800109863281)
# Processing Tag: WBK/TDA/ROW/CEL
# Page: 1, BBox: [230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125]
# PDF Text: DOCUMENT 00 01 15  Page 1
# Drawing rectangle for tag WBK/TDA/ROW/CEL | BBox: Rect(230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125) | Color: (0.8, 0.7254901960784313, 0.4392156862745098)
# Rectangle drawn for tag WBK/TDA/ROW/CEL
# Attempting to add label for tag WBK/TDA/ROW/CEL at position: Point(230.0399932861328, 737.47998046875)
# Text to be printed: 'WBK/TDA/ROW/CEL'
# Label added for tag WBK/TDA/ROW/CEL at position Point(230.0399932861328, 737.47998046875)
# Processing Tag: WBK/TDA/ROW/CEL/DTA/HL3
# Page: 2, BBox: [81.83808135986328, 93.3004379272461, 428.0167541503906, 105.39643859863281]
# PDF Text: USACE / NAVFAC / AFCEC
# 00 01 15 (February 2024)
# Drawing rectangle for tag WBK/TDA/ROW/CEL/DTA/HL3 | BBox: Rect(81.83808135986328, 93.3004379272461, 428.0167541503906, 105.39643859863281) | Color: (0.09411764705882353, 0.2196078431372549, 0.3058823529411765)
# Rectangle drawn for tag WBK/TDA/ROW/CEL/DTA/HL3
# Attempting to add label for tag WBK/TDA/ROW/CEL/DTA/HL3 at position: Point(81.83808135986328, 91.3004379272461)
# Text to be printed: 'WBK/TDA/ROW/CEL/DTA/HL3'
# Label added for tag WBK/TDA/ROW/CEL/DTA/HL3 at position Point(81.83808135986328, 91.3004379272461)
# Processing Tag: WBK/TDA/ROW/CEL/DTA/PRA
# Page: 2, BBox: [81.0, 195.00994873046875, 525.0, 209.00994873046875]
# PDF Text: **************************************************************************
# Drawing rectangle for tag WBK/TDA/ROW/CEL/DTA/PRA | BBox: Rect(81.0, 195.00994873046875, 525.0, 209.00994873046875) | Color: (0.3254901960784314, 0.7411764705882353, 0.7098039215686275)
# Rectangle drawn for tag WBK/TDA/ROW/CEL/DTA/PRA
# Attempting to add label for tag WBK/TDA/ROW/CEL/DTA/PRA at position: Point(81.0, 193.00994873046875)
# Text to be printed: 'WBK/TDA/ROW/CEL/DTA/PRA'
# Label added for tag WBK/TDA/ROW/CEL/DTA/PRA at position Point(81.0, 193.00994873046875)
# Processing Tag: WBK/TDA/ROW/CEL/DTA/BRK
# Page: 2, BBox: [290.0400085449219, 249.97003173828125, 320.0400085449219, 263.97003173828125]
# PDF Text: 02/24
# Drawing rectangle for tag WBK/TDA/ROW/CEL/DTA/BRK | BBox: Rect(290.0400085449219, 249.97003173828125, 320.0400085449219, 263.97003173828125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag WBK/TDA/ROW/CEL/DTA/BRK
# Attempting to add label for tag WBK/TDA/ROW/CEL/DTA/BRK at position: Point(290.0400085449219, 247.97003173828125)
# Text to be printed: 'WBK/TDA/ROW/CEL/DTA/BRK'
# Label added for tag WBK/TDA/ROW/CEL/DTA/BRK at position Point(290.0400085449219, 247.97003173828125)
# Processing page 1.
# Processing Tag: STS/STY/ALN
# Page: 1, BBox: [81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328]
# PDF Text: Preparing Activity:  NAVFAC
# Superseding
# UFGS-00 01 15 (February 2011)
# Drawing rectangle for tag STS/STY/ALN | BBox: Rect(81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328) | Color: (0.3411764705882353, 0.49019607843137253, 0.3254901960784314)
# Rectangle drawn for tag STS/STY/ALN
# Attempting to add label for tag STS/STY/ALN at position: Point(81.83808135986328, 117.2204818725586)
# Text to be printed: 'STS/STY/ALN'
# Label added for tag STS/STY/ALN at position Point(81.83808135986328, 117.2204818725586)
# Processing page 1.
# Processing Tag: STY/ALN
# Page: 1, BBox: [81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328]
# PDF Text: Preparing Activity:  NAVFAC
# Superseding
# UFGS-00 01 15 (February 2011)
# Drawing rectangle for tag STY/ALN | BBox: Rect(81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328) | Color: (0.3411764705882353, 0.49019607843137253, 0.3254901960784314)
# Rectangle drawn for tag STY/ALN
# Attempting to add label for tag STY/ALN at position: Point(81.83808135986328, 117.2204818725586)
# Text to be printed: 'STY/ALN'
# Label added for tag STY/ALN at position Point(81.83808135986328, 117.2204818725586)
# Processing page 1.
# Processing Tag: ALN
# Page: 1, BBox: [81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328]
# PDF Text: Preparing Activity:  NAVFAC
# Superseding
# UFGS-00 01 15 (February 2011)
# Drawing rectangle for tag ALN | BBox: Rect(81.83808135986328, 119.2204818725586, 453.93670654296875, 141.3993682861328) | Color: (0.3411764705882353, 0.49019607843137253, 0.3254901960784314)
# Rectangle drawn for tag ALN
# Attempting to add label for tag ALN at position: Point(81.83808135986328, 117.2204818725586)
# Text to be printed: 'ALN'
# Label added for tag ALN at position Point(81.83808135986328, 117.2204818725586)
# Processing page 2.
# Processing Tag: TDA/COL
# Page: 1, BBox: [230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578]
# PDF Text: SECTION TABLE OF CONTENTS
# Drawing rectangle for tag TDA/COL | BBox: Rect(230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag TDA/COL
# Attempting to add label for tag TDA/COL at position: Point(230.0399932861328, 214.51995849609375)
# Text to be printed: 'TDA/COL'
# Label added for tag TDA/COL at position Point(230.0399932861328, 214.51995849609375)
# Processing Tag: TDA/COL
# Page: 1, BBox: [143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703]
# PDF Text: DIVISION 00 - PROCUREMENT AND CONTRACTING REQUIREMENTS
# Drawing rectangle for tag TDA/COL | BBox: Rect(143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag TDA/COL
# Attempting to add label for tag TDA/COL at position: Point(143.0399932861328, 236.48004150390625)
# Text to be printed: 'TDA/COL'
# Label added for tag TDA/COL at position Point(143.0399932861328, 236.48004150390625)
# Processing Tag: TDA/ROW/CEL/DTA
# Page: 1, BBox: [254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594]
# PDF Text: DOCUMENT 00 01 15
# Drawing rectangle for tag TDA/ROW/CEL/DTA | BBox: Rect(254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag TDA/ROW/CEL/DTA
# Attempting to add label for tag TDA/ROW/CEL/DTA at position: Point(254.0399932861328, 258.44000244140625)
# Text to be printed: 'TDA/ROW/CEL/DTA'
# Label added for tag TDA/ROW/CEL/DTA at position Point(254.0399932861328, 258.44000244140625)
# Processing Tag: TDA/ROW/CEL/DTA
# Page: 1, BBox: [290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125]
# PDF Text: 02/24
# Drawing rectangle for tag TDA/ROW/CEL/DTA | BBox: Rect(290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag TDA/ROW/CEL/DTA
# Attempting to add label for tag TDA/ROW/CEL/DTA at position: Point(290.0400085449219, 301.969970703125)
# Text to be printed: 'TDA/ROW/CEL/DTA'
# Label added for tag TDA/ROW/CEL/DTA at position Point(290.0400085449219, 301.969970703125)
# Processing Tag: TDA/ROW/CEL
# Page: 1, BBox: [83.04000091552734, 436.4800109863281, 311.0400085449219, 448.97003173828125]
# PDF Text: -- End of Section Table of Contents --
# Drawing rectangle for tag TDA/ROW/CEL | BBox: Rect(83.04000091552734, 436.4800109863281, 311.0400085449219, 448.97003173828125) | Color: (0.8, 0.7254901960784313, 0.4392156862745098)
# Rectangle drawn for tag TDA/ROW/CEL
# Attempting to add label for tag TDA/ROW/CEL at position: Point(83.04000091552734, 434.4800109863281)
# Text to be printed: 'TDA/ROW/CEL'
# Label added for tag TDA/ROW/CEL at position Point(83.04000091552734, 434.4800109863281)
# Processing Tag: TDA/ROW/CEL
# Page: 1, BBox: [230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125]
# PDF Text: DOCUMENT 00 01 15  Page 1
# Drawing rectangle for tag TDA/ROW/CEL | BBox: Rect(230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125) | Color: (0.8, 0.7254901960784313, 0.4392156862745098)
# Rectangle drawn for tag TDA/ROW/CEL
# Attempting to add label for tag TDA/ROW/CEL at position: Point(230.0399932861328, 737.47998046875)
# Text to be printed: 'TDA/ROW/CEL'
# Label added for tag TDA/ROW/CEL at position Point(230.0399932861328, 737.47998046875)
# Processing Tag: TDA/ROW/CEL/DTA/HL3
# Page: 2, BBox: [81.83808135986328, 93.3004379272461, 428.0167541503906, 105.39643859863281]
# PDF Text: USACE / NAVFAC / AFCEC
# 00 01 15 (February 2024)
# Drawing rectangle for tag TDA/ROW/CEL/DTA/HL3 | BBox: Rect(81.83808135986328, 93.3004379272461, 428.0167541503906, 105.39643859863281) | Color: (0.09411764705882353, 0.2196078431372549, 0.3058823529411765)
# Rectangle drawn for tag TDA/ROW/CEL/DTA/HL3
# Attempting to add label for tag TDA/ROW/CEL/DTA/HL3 at position: Point(81.83808135986328, 91.3004379272461)
# Text to be printed: 'TDA/ROW/CEL/DTA/HL3'
# Label added for tag TDA/ROW/CEL/DTA/HL3 at position Point(81.83808135986328, 91.3004379272461)
# Processing Tag: TDA/ROW/CEL/DTA/PRA
# Page: 2, BBox: [81.0, 195.00994873046875, 525.0, 209.00994873046875]
# PDF Text: **************************************************************************
# Drawing rectangle for tag TDA/ROW/CEL/DTA/PRA | BBox: Rect(81.0, 195.00994873046875, 525.0, 209.00994873046875) | Color: (0.3254901960784314, 0.7411764705882353, 0.7098039215686275)
# Rectangle drawn for tag TDA/ROW/CEL/DTA/PRA
# Attempting to add label for tag TDA/ROW/CEL/DTA/PRA at position: Point(81.0, 193.00994873046875)
# Text to be printed: 'TDA/ROW/CEL/DTA/PRA'
# Label added for tag TDA/ROW/CEL/DTA/PRA at position Point(81.0, 193.00994873046875)
# Processing Tag: TDA/ROW/CEL/DTA/BRK
# Page: 2, BBox: [290.0400085449219, 249.97003173828125, 320.0400085449219, 263.97003173828125]
# PDF Text: 02/24
# Drawing rectangle for tag TDA/ROW/CEL/DTA/BRK | BBox: Rect(290.0400085449219, 249.97003173828125, 320.0400085449219, 263.97003173828125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag TDA/ROW/CEL/DTA/BRK
# Attempting to add label for tag TDA/ROW/CEL/DTA/BRK at position: Point(290.0400085449219, 247.97003173828125)
# Text to be printed: 'TDA/ROW/CEL/DTA/BRK'
# Label added for tag TDA/ROW/CEL/DTA/BRK at position Point(290.0400085449219, 247.97003173828125)
# Processing page 1.
# Processing Tag: COL
# Page: 1, BBox: [230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578]
# PDF Text: SECTION TABLE OF CONTENTS
# Drawing rectangle for tag COL | BBox: Rect(230.0399932861328, 216.51995849609375, 380.03997802734375, 229.0099639892578) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag COL
# Attempting to add label for tag COL at position: Point(230.0399932861328, 214.51995849609375)
# Text to be printed: 'COL'
# Label added for tag COL at position Point(230.0399932861328, 214.51995849609375)
# Processing page 1.
# Processing Tag: COL
# Page: 1, BBox: [143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703]
# PDF Text: DIVISION 00 - PROCUREMENT AND CONTRACTING REQUIREMENTS
# Drawing rectangle for tag COL | BBox: Rect(143.0399932861328, 238.48004150390625, 467.03997802734375, 250.9700469970703) | Color: (0.6901960784313725, 0.5294117647058824, 0.08627450980392157)
# Rectangle drawn for tag COL
# Attempting to add label for tag COL at position: Point(143.0399932861328, 236.48004150390625)
# Text to be printed: 'COL'
# Label added for tag COL at position Point(143.0399932861328, 236.48004150390625)
# Processing page 1.
# Processing Tag: ROW/CEL/DTA
# Page: 1, BBox: [254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594]
# PDF Text: DOCUMENT 00 01 15
# Drawing rectangle for tag ROW/CEL/DTA | BBox: Rect(254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag ROW/CEL/DTA
# Attempting to add label for tag ROW/CEL/DTA at position: Point(254.0399932861328, 258.44000244140625)
# Text to be printed: 'ROW/CEL/DTA'
# Label added for tag ROW/CEL/DTA at position Point(254.0399932861328, 258.44000244140625)
# Processing Tag: ROW/CEL/DTA
# Page: 1, BBox: [290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125]
# PDF Text: 02/24
# Drawing rectangle for tag ROW/CEL/DTA | BBox: Rect(290.0400085449219, 303.969970703125, 320.0400085449219, 317.969970703125) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag ROW/CEL/DTA
# Attempting to add label for tag ROW/CEL/DTA at position: Point(290.0400085449219, 301.969970703125)
# Text to be printed: 'ROW/CEL/DTA'
# Label added for tag ROW/CEL/DTA at position Point(290.0400085449219, 301.969970703125)
# Processing page 1.
# Processing Tag: CEL/DTA
# Page: 1, BBox: [254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594]
# PDF Text: DOCUMENT 00 01 15
# Drawing rectangle for tag CEL/DTA | BBox: Rect(254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594) | Color: (0.396078431372549, 0.8392156862745098, 0.4392156862745098)
# Rectangle drawn for tag CEL/DTA
# Attempting to add label for tag CEL/DTA at position: Point(254.0399932861328, 258.44000244140625)
# Text to be printed: 'CEL/DTA'
# Label added for tag CEL/DTA at position Point(254.0399932861328, 258.44000244140625)
# Processing page 1.
# Processing Tag: DTA
# Page: 1, BBox: [254.0399932861328, 260.44000244140625, 356.03997802734375, 272.9300231933594]
# PDF Text: DOCUMENT 00 01 15
# ...
# Processing Tag: BRK
# Page: 3, BBox: [81.0, 225.969970703125, 525.0, 239.969970703125]
# PDF Text: **************************************************************************
# Drawing rectangle for tag BRK | BBox: Rect(81.0, 225.969970703125, 525.0, 239.969970703125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag BRK
# Attempting to add label for tag BRK at position: Point(81.0, 223.969970703125)
# Text to be printed: 'BRK'
# Label added for tag BRK at position Point(81.0, 223.969970703125)
# Processing page 3.
# Processing Tag: BRK
# Page: 3, BBox: [83.04000091552734, 248.44000244140625, 533.0400390625, 337.9700012207031]
# PDF Text: The following reference drawing[s] [is][are] intended only to show the
# original construction.  Drawing[s] [is][are] the property of the
# Government and shall not be used for any purpose other than that intended
# by the contract.[  The drawing[s] [is][are] [half-][full-]size.  Full-size
# drawings are available at the bidder's or Contractor's expense.[
# Information on procuring these full-size drawings may be obtained from the
# Contracting Officer.][  Full size drawings may be inspected during regular
# working hours at[ the office of the Contracting Officer.][ the station.]]
# Drawing rectangle for tag BRK | BBox: Rect(83.04000091552734, 248.44000244140625, 533.0400390625, 337.9700012207031) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag BRK
# Attempting to add label for tag BRK at position: Point(83.04000091552734, 246.44000244140625)
# Text to be printed: 'BRK'
# Label added for tag BRK at position Point(83.04000091552734, 246.44000244140625)
# Processing page 3.
# Processing Tag: STL
# Page: 3, BBox: [73.91520690917969, 348.465576171875, 200.63812255859375, 359.2569580078125]
# PDF Text: NAVFAC DWG NO.
# TITLE
# Drawing rectangle for tag STL | BBox: Rect(73.91520690917969, 348.465576171875, 200.63812255859375, 359.2569580078125) | Color: (0.3843137254901961, 0.13725490196078433, 0.09019607843137255)
# Rectangle drawn for tag STL
# Attempting to add label for tag STL at position: Point(73.91520690917969, 346.465576171875)
# Text to be printed: 'STL'
# Label added for tag STL at position Point(73.91520690917969, 346.465576171875)
# Processing page 3.
# Processing Tag: BRK
# Page: 3, BBox: [73.91520690917969, 370.0655822753906, 211.00613403320312, 380.8569641113281]
# PDF Text: [_____]
# [_____]
# Drawing rectangle for tag BRK | BBox: Rect(73.91520690917969, 370.0655822753906, 211.00613403320312, 380.8569641113281) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag BRK
# Attempting to add label for tag BRK at position: Point(73.91520690917969, 368.0655822753906)
# Text to be printed: 'BRK'
# Label added for tag BRK at position Point(73.91520690917969, 368.0655822753906)
# Processing page 3.
# Processing Tag: DTE
# Page: 3, BBox: [72.0, 393.5199890136719, 204.0, 406.010009765625]
# PDF Text: ]][1.3.2   Boring Logs
# Drawing rectangle for tag DTE | BBox: Rect(72.0, 393.5199890136719, 204.0, 406.010009765625) | Color: (0.49019607843137253, 0.4470588235294118, 0.2784313725490196)
# Rectangle drawn for tag DTE
# Attempting to add label for tag DTE at position: Point(72.0, 391.5199890136719)
# Text to be printed: 'DTE'
# Label added for tag DTE at position Point(72.0, 391.5199890136719)
# Processing page 3.
# Processing Tag: BRK
# Page: 3, BBox: [81.0, 414.9700012207031, 525.0, 428.9700012207031]
# PDF Text: **************************************************************************
# Drawing rectangle for tag BRK | BBox: Rect(81.0, 414.9700012207031, 525.0, 428.9700012207031) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag BRK
# Attempting to add label for tag BRK at position: Point(81.0, 412.9700012207031)
# Text to be printed: 'BRK'
# Label added for tag BRK at position Point(81.0, 412.9700012207031)
# Skipping tag NTE with invalid or missing page number.
# Processing page 3.
# Processing Tag: BRK
# Page: 3, BBox: [144.9600067138672, 426.010009765625, 456.96002197265625, 506.0099792480469]
# PDF Text: NOTE:  Select this paragraph BORING LOGS or
# paragraph SUBSURFACE DATA if the boring logs and
# subsurface information are not already incorporated
# in the drawings.  Use the first paragraph if boring
# logs are available and the second if they are
# incorporated into a soils report or if only a soils
# report is available.
# Drawing rectangle for tag BRK | BBox: Rect(144.9600067138672, 426.010009765625, 456.96002197265625, 506.0099792480469) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag BRK
# Attempting to add label for tag BRK at position: Point(144.9600067138672, 424.010009765625)
# Text to be printed: 'BRK'
# Label added for tag BRK at position Point(144.9600067138672, 424.010009765625)
# Processing page 3.
# Processing Tag: AST
# Page: 3, BBox: [81.0, 502.92999267578125, 525.0, 516.9299926757812]
# PDF Text: **************************************************************************
# Drawing rectangle for tag AST | BBox: Rect(81.0, 502.92999267578125, 525.0, 516.9299926757812) | Color: (0.9254901960784314, 0.7607843137254902, 0.5411764705882353)
# Rectangle drawn for tag AST
# Attempting to add label for tag AST at position: Point(81.0, 500.92999267578125)
# Text to be printed: 'AST'
# Label added for tag AST at position Point(81.0, 500.92999267578125)
# Processing page 3.
# Processing Tag: BRK
# Page: 3, BBox: [83.04000091552734, 525.5199584960938, 533.0400390625, 592.969970703125]
# PDF Text: The Government does not guarantee that borings indicate actual conditions,
# except for the exact locations and the time that they were made.[
# Subsurface data, not specified or indicated, have been obtained by the
# Government at this station.  The data are available for examination by
# prospective bidders[ in the office of the Contracting Officer][ at the
# station].]
# Drawing rectangle for tag BRK | BBox: Rect(83.04000091552734, 525.5199584960938, 533.0400390625, 592.969970703125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag BRK
# Attempting to add label for tag BRK at position: Point(83.04000091552734, 523.5199584960938)
# Text to be printed: 'BRK'
# Label added for tag BRK at position Point(83.04000091552734, 523.5199584960938)
# Processing page 3.
# Processing Tag: NPR/SCP
# Page: 3, BBox: [72.0, 602.4400024414062, 222.0, 614.9299926757812]
# PDF Text: ][1.3.3   Subsurface Data
# Drawing rectangle for tag NPR/SCP | BBox: Rect(72.0, 602.4400024414062, 222.0, 614.9299926757812) | Color: (0.8980392156862745, 0.5568627450980392, 0.011764705882352941)
# Rectangle drawn for tag NPR/SCP
# Attempting to add label for tag NPR/SCP at position: Point(72.0, 600.4400024414062)
# Text to be printed: 'NPR/SCP'
# Label added for tag NPR/SCP at position Point(72.0, 600.4400024414062)
# Processing page 3.
# Processing Tag: SCP
# Page: 3, BBox: [72.0, 602.4400024414062, 222.0, 614.9299926757812]
# PDF Text: ][1.3.3   Subsurface Data
# Drawing rectangle for tag SCP | BBox: Rect(72.0, 602.4400024414062, 222.0, 614.9299926757812) | Color: (0.8980392156862745, 0.5568627450980392, 0.011764705882352941)
# Rectangle drawn for tag SCP
# Attempting to add label for tag SCP at position: Point(72.0, 600.4400024414062)
# Text to be printed: 'SCP'
# Label added for tag SCP at position Point(72.0, 600.4400024414062)
# Processing page 3.
# Processing Tag: BRK
# Page: 3, BBox: [72.0, 679.47998046875, 234.0, 691.969970703125]
# PDF Text: ]]    -- End of Document --
# Drawing rectangle for tag BRK | BBox: Rect(72.0, 679.47998046875, 234.0, 691.969970703125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag BRK
# Attempting to add label for tag BRK at position: Point(72.0, 677.47998046875)
# Text to be printed: 'BRK'
# Label added for tag BRK at position Point(72.0, 677.47998046875)
# Processing page 3.
# Processing Tag: BRK
# Page: 3, BBox: [230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125]
# PDF Text: DOCUMENT 00 01 15  Page 3
# Drawing rectangle for tag BRK | BBox: Rect(230.0399932861328, 739.47998046875, 380.03997802734375, 751.969970703125) | Color: (0.4235294117647059, 0.6313725490196078, 0.4235294117647059)
# Rectangle drawn for tag BRK
# Attempting to add label for tag BRK at position: Point(230.0399932861328, 737.47998046875)
# Text to be printed: 'BRK'
# Label added for tag BRK at position Point(230.0399932861328, 737.47998046875)
# Skipping tag NPR with invalid or missing page number.
# Skipping tag URL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NPR with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NPR with invalid or missing page number.
# Skipping tag URL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag AST with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag PRT with invalid or missing page number.
# Skipping tag TTL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag SPT with invalid or missing page number.
# Skipping tag TTL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag TXT with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag SPT with invalid or missing page number.
# Skipping tag TTL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NTE with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag AST with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NPR with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag AST with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag TXT with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag TAB with invalid or missing page number.
# Skipping tag WBK with invalid or missing page number.
# Skipping tag STS with invalid or missing page number.
# Skipping tag TDA with invalid or missing page number.
# Skipping tag COL with invalid or missing page number.
# Skipping tag COL with invalid or missing page number.
# Skipping tag COL with invalid or missing page number.
# Skipping tag COL with invalid or missing page number.
# Skipping tag ROW with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag ROW with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag SPT with invalid or missing page number.
# Skipping tag TTL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag TXT with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag SPT with invalid or missing page number.
# Skipping tag TTL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NTE with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag AST with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NPR with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag AST with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag TXT with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag TAB with invalid or missing page number.
# Skipping tag WBK with invalid or missing page number.
# Skipping tag STS with invalid or missing page number.
# Skipping tag TDA with invalid or missing page number.
# Skipping tag COL with invalid or missing page number.
# Skipping tag COL with invalid or missing page number.
# Skipping tag ROW with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag ROW with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag CEL with invalid or missing page number.
# Skipping tag DTA with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag SPT with invalid or missing page number.
# Skipping tag TTL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NTE with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag AST with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NPR with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag AST with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag TXT with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag SPT with invalid or missing page number.
# Skipping tag TTL with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag NED with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag TXT with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Skipping tag EOD with invalid or missing page number.
# Skipping tag BRK with invalid or missing page number.
# Annotation process completed.
# Saving annotated PDF to: /content/annotated_UFGS_00_01_15.pdf
# Annotated PDF saved successfully.
