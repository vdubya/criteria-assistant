# %% [markdown]
# <a href="https://colab.research.google.com/github/vdubya/criteria-assistant/blob/main/UFC_DownloadAllWithMetadata_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =======================
# Step 0: Install dependencies
# =======================
# !pip install requests beautifulsoup4

# =======================
# Step 1: Imports and Config
# =======================
import requests
from bs4 import BeautifulSoup
import json
import csv
import re
import os
import time
import zipfile
from datetime import datetime
from urllib.parse import urlparse

# =======================
# Config Flags
# =======================
DEBUG_LEVEL = 2
PARTIAL_RUN = False
FORCE_DOWNLOAD = False
METADATA_ONLY = False
FILENAME_SUFFIX_DATE = False
STATUS_FILTERS = {"Active", "Inactive", "Archived", "Reference"}
RUN_UNIT_TESTS = False

BASE_URL = "https://www.wbdg.org"
URLS = {
    "active_page1": "https://www.wbdg.org/dod/ufc?field_status_value=1&field_series_value=All",
    "active_page2": "https://www.wbdg.org/dod/ufc?field_status_value=1&field_series_value=All&page=1",
    "inactive": "https://www.wbdg.org/dod/ufc?field_status_value=2&field_series_value=All",
    "archived": "https://www.wbdg.org/dod/ufc?field_status_value=3&field_series_value=All"
}

ufc_complete_downloads = [
    ("UFC Complete Volume 1", "https://www.wbdg.org/FFC/DOD/UFC/UFC_Complete_1-200-01_thru_3-220-20.pdf"),
    ("UFC Complete Volume 2", "https://www.wbdg.org/FFC/DOD/UFC/UFC_Complete_3-230-01_thru_3-340-02.pdf"),
    ("UFC Complete Volume 3", "https://www.wbdg.org/FFC/DOD/UFC/UFC_Complete_3-400-02_thru_3-810-01N.pdf"),
    ("UFC Complete Volume 4", "https://www.wbdg.org/FFC/DOD/UFC/UFC_Complete_4-010-01_thru_4-159-03.pdf"),
    ("UFC Complete Volume 5", "https://www.wbdg.org/FFC/DOD/UFC/UFC_Complete_FC_4-171-06N_thru_4-860_03.pdf")
]

def debug(msg, level=1):
    if DEBUG_LEVEL >= level:
        print(f"[DEBUG] {msg}")

def parse_title_fields(raw_title):
    if "Replaced by" in raw_title:
        parts = raw_title.split("Replaced by")
        main_part, replaced_by = parts[0].strip().rstrip(","), "Replaced by " + parts[1].strip()
    else:
        main_part, replaced_by = raw_title, None
    match = re.match(r"^(UFC|FC)\s+([\d\-A-Z]+)\s+(.*)", main_part)
    return {
        "ufc_prefix": match.group(1) if match else None,
        "ufc_number": match.group(2) if match else None,
        "title": match.group(3) if match else main_part,
        "replaced_by": replaced_by
    }

def detect_ufc_type_from_url(url):
    basename = os.path.basename(url)
    if basename.upper().startswith("FC"):
        return "FC"
    elif basename.upper().startswith("UFC"):
        return "UFC"
    return "Unknown"

def fetch_metadata(detail_url, ufc_number=None):
    response = requests.get(detail_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    full_name = soup.find("h1", class_="page-title").text.strip()

    if full_name.strip().lower() == "ufc complete":
        debug(f"⏭️ Skipped parsing for UFC Complete at: {detail_url}", 1)
        return None

    metadata = {
        "ufc_full_name": full_name
    }

    if not ufc_number:
        m = re.search(r'(UFC|FC)\s+(\d-\d{3}-\d{2}[A-Z]*)', metadata["ufc_full_name"])
        if m:
            ufc_number = m.group(2)
            metadata["ufc_type"] = m.group(1)
    metadata["ufc_number"] = ufc_number
    metadata["ufc_type"] = metadata.get("ufc_type") or "UFC"
    metadata["ufc_title"] = metadata["ufc_full_name"].replace(f"{metadata['ufc_type']} {ufc_number} ", "") if ufc_number else metadata["ufc_full_name"]

    status_div = soup.select_one('div.field--name-field-status .field__item')
    metadata["status"] = status_div.text.strip() if status_div else "Unknown"

    pub_time = soup.select_one('div.field--name-field-published-date .field__item time')
    metadata["publish_date"] = pub_time.text.strip() if pub_time else None

    change_time = soup.select_one('div.field--name-field-cngrevdt .field__item time')
    metadata["change_date"] = change_time.text.strip() if change_time else None

    pages_div = soup.select_one('div.field--name-field-pages .field__item')
    metadata["pages"] = int(pages_div.text.strip()) if pages_div and pages_div.text.strip().isdigit() else None

    series_items = soup.select('div.field--name-field-series .field__item')
    metadata["series"] = " | ".join(item.text.strip() for item in series_items) if series_items else None

    link_tag = soup.select_one('div.field--name-field-viewdown a[href$=".pdf"]')
    if link_tag:
        download_url = BASE_URL + link_tag['href']
        filename = os.path.basename(link_tag['href'])
    else:
        download_url = None
        filename = None

    metadata["download_link"] = download_url
    metadata["filename"] = filename
    metadata["metadata_link"] = detail_url

    summary_div = soup.select_one('div.field--name-field-summary .field__item')
    metadata["summary"] = summary_div.get_text(strip=True) if summary_div else ""

    metadata["ccr_url"] = f"https://cms.wbdg.org/ccrs/new?ufc={ufc_number}" if ufc_number else None

    metadata["superseded_versions"] = []
    superseded_divs = soup.select('div.field--name-field-supervers .field__item')
    for div in superseded_divs:
        a_tag = div.find("a")
        date_tag = div.find("small")
        if a_tag:
            href = BASE_URL + a_tag["href"]
            title = a_tag.get_text(strip=True).replace(u'\xa0', ' ')
            date = date_tag.get_text(strip=True).strip("()") if date_tag else None
            metadata["superseded_versions"].append({
                "title": title,
                "url": href,
                "date": date,
                "filename": os.path.basename(href)  # <--- ✅ Added here
            })

    metadata["superseded_versions_count"] = len(metadata["superseded_versions"])

    if metadata["ufc_number"] == "1-200-01":
        run_tests(metadata)

    return metadata

def scrape_ufc_list(url):
    debug(f"[INFO] Scraping UFC list from: {url}", 1)
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, "html.parser")
    rows = soup.find_all("tr")
    entries = []

    for i, row in enumerate(rows[:10] if PARTIAL_RUN else rows):
        cols = row.find_all("td")
        if len(cols) < 4:
            continue
        raw_title = cols[0].get_text(strip=True)
        parsed = parse_title_fields(raw_title)
        detail_url = BASE_URL + cols[0].find("a")["href"]

        metadata = fetch_metadata(detail_url, ufc_number=parsed["ufc_number"])
        if not metadata:
            continue

        entry = {
            "ufc_full_name": metadata["ufc_full_name"],
            "ufc_number": metadata["ufc_number"],
            "ufc_prefix": parsed["ufc_prefix"],
            "ufc_title": metadata["ufc_title"],
            "ufc_type": metadata["ufc_type"],
            "filename": metadata["filename"],  # <--- ✅ Added here
            "pages": metadata.get("pages"),
            "series": metadata.get("series"),
            "status": metadata["status"],
            "publish_date": metadata["publish_date"],
            "change_date": metadata["change_date"],
            "archived / rescinded date": None,
            "replaced_by": parsed["replaced_by"],
            "download_link": metadata["download_link"],
            "metadata_link": metadata["metadata_link"],
            "summary": metadata["summary"],
            "ccr_url": metadata["ccr_url"],
            "superseded_versions": metadata["superseded_versions"],
            "superseded_versions_count": metadata["superseded_versions_count"]
        }

        debug(json.dumps(entry, indent=2), level=2)
        entries.append(entry)
        time.sleep(0.25)

    return entries
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.7.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.1)

# %%
def run_tests(metadata):
    debug("🔍 Running unit tests for UFC 1-200-01...", 1)

    def assert_equal(field, actual, expected):
        if actual != expected:
            raise AssertionError(f"[FAIL] {field} mismatch:\n  - Expected: {expected}\n  - Actual:   {actual}")
        debug(f"[PASS] {field}: {actual}", 2)

    assert_equal("ufc_number", metadata["ufc_number"], "1-200-01")
    assert metadata["ufc_type"].startswith(("UFC", "FC")), f"[FAIL] ufc_type: {metadata['ufc_type']} must start with 'UFC' or 'FC'"
    debug(f"[PASS] ufc_type: {metadata['ufc_type']}", 2)

    assert_equal("status", metadata["status"], "Active")
    assert_equal("ufc_full_name", metadata["ufc_full_name"], "UFC 1-200-01 DoD Building Code, with Change 4")
    assert_equal("ufc_title", metadata["ufc_title"], "DoD Building Code, with Change 4")
    assert_equal("download_link", metadata["download_link"], "https://www.wbdg.org/FFC/DOD/UFC/ufc_1_200_01_2022_c4.pdf")
    assert_equal("filename", metadata["filename"], "ufc_1_200_01_2022_c4.pdf")
    assert_equal("metadata_link", metadata["metadata_link"], "https://www.wbdg.org/dod/ufc/ufc-1-200-01")
    assert_equal("change_date", metadata["change_date"], "12/17/2024")
    assert_equal("publish_date", metadata["publish_date"], "09/01/2022")
    assert_equal("superseded_versions_count", metadata["superseded_versions_count"], 21)

    expected_titles = [
        "UFC 1-200-01 DoD Building Code, with Change 3",
        "UFC 1-200-01 DoD Building Code, with Change 2",
        "UFC 1-200-01 DoD Building Code, with Change 1",
        "UFC 1-200-01 DoD Building Code",
        "UFC 1-200-01 DoD Building Code, with Change 1",
        "UFC 1-200-01 DoD Building Code",
        "UFC 1-200-01 DoD Building Code (General Building Requirements), with Change 2",
        "UFC 1-200-01 DoD Building Code (General Building Requirements), with Change 1",
        "UFC 1-200-01 DoD Building Code (General Building Requirements)",
        "UFC 1-200-01 General Building Requirements, with Change 3",
        "UFC 1-200-01 General Building Requirements, with Change 2",
        "UFC 1-200-01 General Building Requirements, with Change 1",
        "UFC 1-200-01 General Building Requirements",
        "UFC 1-200-01 General Building Requirements, with Change 2",
        "UFC 1-200-01 General Building Requirements, with Change 1",
        "UFC 1-200-01 General Building Requirements",
        "UFC 1-200-01 General Building Requirements, with Change 2",
        "UFC 1-200-01 General Building Requirements, with Change 1",
        "UFC 1-200-01 General Building Requirements",
        "UFC 1-200-01 General Building Requirements",
        "UFC 1-200-01 General Building Requirements"
    ]

    expected_dates = [
        "02-26-2024", "06-12-2023", "02-24-2023", "09-01-2022", "10-01-2020", "10-08-2019",
        "11-01-2018", "02-01-2018", "06-20-2016", "08-01-2015", "11-01-2014", "09-01-2013",
        "07-01-2013", "11-28-2011", "07-19-2011", "07-01-2010", "01-27-2010", "05-07-2009",
        "07-01-2007", "07-01-2005", "07-31-2002"
    ]

    expected_filenames = [
        "ufc_1_200_01_2022_c3.pdf", "ufc_1_200_01_2022_c2.pdf", "ufc_1_200_01_2022_c1.pdf", "ufc_1_200_01_2022.pdf",
        "ufc_1_200_01_2019_c1.pdf", "ufc_1_200_01_2019.pdf", "ufc_1_200_01_2016_c2.pdf", "ufc_1_200_01_2016_c1.pdf",
        "ufc_1_200_01_2016.pdf", "ufc_1_200_01_2013_c3.pdf", "ufc_1_200_01_2013_c2.pdf", "ufc_1_200_01_2013_c1.pdf",
        "ufc_1_200_01_2013.pdf", "ufc_1_200_01_2010_c2.pdf", "ufc_1_200_01_2010_c1.pdf", "ufc_1_200_01_2010.pdf",
        "ufc_1_200_01_2007_c2.pdf", "ufc_1_200_01_2007_c1.pdf", "ufc_1_200_01_2007.pdf", "ufc_1_200_01_2005.pdf",
        "ufc_1_200_01_2002.pdf"
    ]

    for i, version in enumerate(metadata["superseded_versions"]):
        try:
            assert_equal(f"superseded_versions[{i}].title", version["title"], expected_titles[i])
            assert_equal(f"superseded_versions[{i}].date", version["date"], expected_dates[i])
            assert_equal(f"superseded_versions[{i}].filename", version["filename"], expected_filenames[i])
        except AssertionError as e:
            raise AssertionError(f"Superseded version mismatch at index {i}:\n{str(e)}")

    debug("✅ Unit tests passed for UFC 1-200-01.", 1)

# =======================
# Main Execution
# =======================
if RUN_UNIT_TESTS:
    metadata = fetch_metadata("https://www.wbdg.org/dod/ufc/ufc-1-200-01")
    debug(json.dumps(metadata, indent=2), level=1)
else:
    all_ufcs = []
    for url in URLS.values():
        all_ufcs += scrape_ufc_list(url)

    for name, url in ufc_complete_downloads:
        all_ufcs.append({
            "ufc_full_name": name,
            "ufc_number": None,
            "ufc_prefix": None,
            "ufc_title": name,
            "ufc_type": "UFC",
            "filename": os.path.basename(url),
            "pages": None,
            "series": None,
            "status": "Reference",
            "publish_date": "06/02/2025",
            "change_date": None,
            "archived / rescinded date": None,
            "replaced_by": None,
            "download_link": url,
            "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-complete",
            "summary": "Active UFCs combined into five PDF documents",
            "ccr_url": None,
            "superseded_versions": [],
            "superseded_versions_count": 0
        })

    # === JSON Output ===
    with open("wbdg_ufc_metadata.json", "w", encoding="utf-8") as f:
        json.dump(all_ufcs, f, indent=2, ensure_ascii=False)

    # === CSV Output (flattened) ===
    def flatten(entry):
        flat_entry = entry.copy()
        flat_entry["superseded_version_titles"] = "|".join(
            [str(v.get("title", "") or "") for v in entry.get("superseded_versions", [])]
        )
        flat_entry["superseded_version_dates"] = "|".join(
            [str(v.get("date", "") or "") for v in entry.get("superseded_versions", [])]
        )
        flat_entry.pop("superseded_versions", None)
        return flat_entry

    flattened = [flatten(e) for e in all_ufcs]

    csv_fieldnames = list(flattened[0].keys())
    with open("wbdg_ufc_metadata.csv", "w", newline='', encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=csv_fieldnames)
        writer.writeheader()
        writer.writerows(flattened)

    # === Optional PDF Download + ZIP ===
    if not METADATA_ONLY:
        os.makedirs("wbdg_ufc_downloads", exist_ok=True)
        total_files = sum(1 for e in all_ufcs if e.get("download_link"))

        for idx, entry in enumerate(all_ufcs, start=1):
            url = entry["download_link"]
            if not url:
                continue
            filename = os.path.basename(urlparse(url).path)
            if FILENAME_SUFFIX_DATE and entry.get("change_date"):
                try:
                    dt = datetime.strptime(entry["change_date"], "%m-%d-%Y")
                    filename = f"{entry['ufc_number']} [{dt.date()}].pdf"
                except:
                    pass
            status_dir = os.path.join("wbdg_ufc_downloads", (entry["status"] or "Unknown").capitalize())
            os.makedirs(status_dir, exist_ok=True)
            filepath = os.path.join(status_dir, filename)

            if FORCE_DOWNLOAD or not os.path.exists(filepath):
                try:
                    file_data = requests.get(url).content
                    with open(filepath, "wb") as f:
                        f.write(file_data)
                    debug(f"[{idx}/{total_files}] ✅ Downloaded: {filename}", 1)
                except Exception as e:
                    debug(f"[{idx}/{total_files}] ❌ Failed download: {filename} — {e}", 1)
            else:
                debug(f"[{idx}/{total_files}] ⏭️ Skipped (exists): {filename}", 1)

        # Create ZIP and include metadata files at root
        with zipfile.ZipFile("wbdg_ufc_downloads.zip", "w") as zipf:
            zipf.write("wbdg_ufc_metadata.json")
            zipf.write("wbdg_ufc_metadata.csv")
            for root, _, files in os.walk("wbdg_ufc_downloads"):
                for file in files:
                    full_path = os.path.join(root, file)
                    arcname = os.path.relpath(full_path, start="wbdg_ufc_downloads")
                    zipf.write(full_path, arcname=arcname)

        debug("📦 All UFC files and metadata zipped.", 1)
    else:
        debug("✅ Metadata-only mode complete.", 1)
# Out:
# Streaming output truncated to the last 5000 lines.
#   "ufc_title": "Buildings - Arctic and Subarctic Construction",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_130_07_2004.pdf",
#   "pages": 70,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-100: ARCHITECTURE AND INTERIOR DESIGN",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_130_07_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-130-07",
#   "summary": "The purpose of this manual is to provide criteria and guidance for the design of buildings in arctic and subarctic regions.  This manual supplements TM 5-852-1/AFR 88-19, Volume 1.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-130-07",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-190-03A X-Ray Shielding",
#   "ufc_number": "3-190-03A",
#   "ufc_prefix": "UFC",
#   "ufc_title": "X-Ray Shielding",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_190_03a_2003.pdf",
#   "pages": 34,
#   "series": null,
#   "status": "Inactive",
#   "publish_date": "11/17/2003",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_190_03a_2003.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-190-03a",
#   "summary": "This technical manual is a guide for designing, constructing, and certifying dental, diagnostic, and therapeutic radiation exposure rooms using equipment having energies up to 10 million electron volts (MeV).",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-190-03A",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-190-07N Food Service Equipment Operation and Maintenance",
#   "ufc_number": "3-190-07N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Food Service Equipment Operation and Maintenance",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_190_07n_2004.pdf",
#   "pages": 151,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-100: ARCHITECTURE AND INTERIOR DESIGN",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_190_07n_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-190-07n",
#   "summary": "Chapter 1 introduces this UFC and provides a listing of references to other Tri-Service documents closely related to the subject. Appendix A contains the full text copy of the previously released Military Handbook (MIL-HDBK) on this subject. This UFC serves as criteria until such time as the full text UFC is developed from the MIL HDBK and other sources.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-190-07N",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-210-04 Children's Outdoor Play Area",
#   "ufc_number": "3-210-04",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Children's Outdoor Play Area",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_210_04_2004.pdf",
#   "pages": 95,
#   "series": null,
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_210_04_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-210-04",
#   "summary": "This manual establishes guidance for planning and designing unsupervised outdoor play areas to meet child safety and child development requirements.  By applying this guidance, a designer can create play areas at military installations that will provide a play program that meets the needs of children with and without disabilities.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-210-04",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-220-04FA Backfill for Subsurface Structures",
#   "ufc_number": "3-220-04FA",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Backfill for Subsurface Structures",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_220_04fa_2004.pdf",
#   "pages": 60,
#   "series": null,
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/ufc_3_220_04fa_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-220-04fa",
#   "summary": "This manual is for the guidance of designers, specification writers, and especially field personnel engaged in designing, planning, and conducting earthwork operations around major deep-seated or subsurface structures.  The greatest deficiencies in earthwork operations around deep-seated or subsurface structures occur because of improper backfilling procedures and inadequate construction control during this phase of the work. Therefore, primary emphasis in this manual is on backfilling procedures. Design and planning considerations, evaluation and selection of materials, and other phases of earthwork construction are discussed where pertinent to successful backfill operations. Although the information in this manual is primarily applicable to backfilling around large and important deep-seated or buried structures, it is also applicable in varying degrees to backfilling operations around all structures, including conduits.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-220-04FA",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-220-05 Dewatering and Groundwater Control",
#   "ufc_number": "3-220-05",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Dewatering and Groundwater Control",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_220_05_2004.pdf",
#   "pages": 161,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-200: CIVIL / GEOTECHNICAL / LANDSCAPE ARCHITECTURE",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_220_05_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-220-05",
#   "summary": "This manual provides guidance for the planning, design, supervision, construction, and operation of dewatering and pressure relief systems and of seepage cutoffs for deep excavations for structures. It presents: description of various methods of dewatering and pressure relief; techniques for determining groundwater conditions, characteristics of pervious aquifers, and dewatering requirements; guidance for specifying requirements for dewatering and seepage control measures; guidance for determining the adequacy of designs and plans prepared by contractors; procedures for designing, installing, operating, and checking the performance of dewatering systems for various types of excavations; and descriptions and design of various types of cutoffs for controlling groundwater.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-220-05",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-220-06 Grouting Methods and Equipment",
#   "ufc_number": "3-220-06",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Grouting Methods and Equipment",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_220_06_2004.pdf",
#   "pages": 91,
#   "series": null,
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_220_06_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-220-06",
#   "summary": "This manual was prepared to provide guidance in the use of pressure grouting as a means to correct existing or anticipated subsurface problems. Information on procedures, materials, and equipment for use in planning and executing a grouting project i\u2019s included, and types of problems that might be solved by pressure grouting are discussed. Methods of pressure grouting that have proven to be effective are described, and various types of grouts and their properties are listed.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-220-06",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-220-08FA Engineering Use of Geotextiles",
#   "ufc_number": "3-220-08FA",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Engineering Use of Geotextiles",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_220_08fa_2004.pdf",
#   "pages": 62,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-200: CIVIL / GEOTECHNICAL / LANDSCAPE ARCHITECTURE",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_220_08fa_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-220-08fa",
#   "summary": "This manual describes various geotextiles, test methods for evaluating their properties, and recommended design and installation procedures.  This manual covers physical properties, functions, design methods, design details and construction procedures for geotextiles as used in pavements, railroad beds, retaining wall earth embankment, rip-rap, concrete revetment, and drain construction.  Geotextile functions described include pavements, filtration and drainage, reinforced embankments, railroads, erosion and sediment control, and earth retaining walls. This manual does not cover the use of other geosynthetics such as geogrids, geonets, geomembranes, plastic strip drains, composite products and products made from natural cellulose fibers.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-220-08FA",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-230-06A Subsurface Drainage, with Changes 1-2",
#   "ufc_number": "3-230-06A",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Subsurface Drainage, with Changes 1-2",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_230_06a_2004_c2.pdf",
#   "pages": 75,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-200: CIVIL / GEOTECHNICAL / LANDSCAPE ARCHITECTURE",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_230_06a_2004_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-230-06a",
#   "summary": "This manual provides guidance for the design and construction of subsurface drainage facilities for airfields, roads, streets, parking lots, and other paved areas.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-230-06A",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-240-03N Wastewater Treatment System Augmenting Handbook Operation and Maintenance",
#   "ufc_number": "3-240-03N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Wastewater Treatment System Augmenting Handbook Operation and Maintenance",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_240_03n_2004.pdf",
#   "pages": 143,
#   "series": null,
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_240_03n_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-240-03n",
#   "summary": "This UFC is comprised of two sections.  Chapter 1 introduces this UFC and provides a listing of references to other Tri-Service documents closely related to the subject.  Appendix A contains the full text copy of the previously released Military Handbook (MIL-HNBK) on this subject.  This UFC serves as criteria until such time as the full text UFC is developed from the MIL-HNBK and other sources.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-240-03N",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-240-05A Solid Waste Incineration",
#   "ufc_number": "3-240-05A",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Solid Waste Incineration",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_240_05a_2004.pdf",
#   "pages": 99,
#   "series": null,
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_240_05a_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-240-05a",
#   "summary": "This manual provides guidance for the planning and concept design of municipal waste incineration plants.  This manual introduces issues which must be considered to determine the cost effectiveness of municipal waste incineration as a complement to a comprehensive solid waste program.  This manual introduces the designer to the basics of incineration, incineration technologies, pollution control, and overall incinerator plant design requirements.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-240-05A",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-240-10A Sanitary Landfill",
#   "ufc_number": "3-240-10A",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Sanitary Landfill",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_240_10a_2004.pdf",
#   "pages": 38,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-200: CIVIL / GEOTECHNICAL / LANDSCAPE ARCHITECTURE",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_240_10a_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-240-10a",
#   "summary": "This manual establishes the minimum design requirements for sanitary landfills, provides engineering criteria for construction, and lists recommended practices for planning and feasibility studies.  This manual explains applicable laws and regulations, solid waste disposal alternatives, site selection considerations, design criteria, construction methods, and operating practices for sanitary landfills. Only disposal of non-hazardous solid waste at Army installations is addressed. The information described herein is applicable to feasibility studies as well as design work.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-240-10A",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-250-10FA Pavement Design for Roads, Streets and Open Storage Areas, Elastic Layered Methods",
#   "ufc_number": "3-250-10FA",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Pavement Design for Roads, Streets and Open Storage Areas, Elastic Layered Methods",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_250_10fa_2004.pdf",
#   "pages": 53,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-200: CIVIL / GEOTECHNICAL / LANDSCAPE ARCHITECTURE",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_250_10fa_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-250-10fa",
#   "summary": "This manual provides an elastic layered method for the thickness design of pavements for roads, streets, walks, and open storage areas at US Army and Air Force installations for the loadings and conditions set forth herein.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-250-10FA",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-280-01A Guidance for Ground Water/Fuel Extraction and Ground Water Injection Systems",
#   "ufc_number": "3-280-01A",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Guidance for Ground Water/Fuel Extraction and Ground Water Injection Systems",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_280_01a_2004.pdf",
#   "pages": 176,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-200: CIVIL / GEOTECHNICAL / LANDSCAPE ARCHITECTURE",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_280_01a_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-280-01a",
#   "summary": "The purpose of this design guide (DG) provides guidance for the basic design, installation and operation of ground water extraction and ground water injection systems for the cleanup of contaminated ground water, exclusive of any treatment systems.  General guidance on ground water extraction (GWE) already exists.  The intent of this DG is to document lessons learned from expedience and to provide a systematic approach to the installation, operation and trouble-shooting of systems.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-280-01A",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-280-03 Army Plate and Frame Filter Press",
#   "ufc_number": "3-280-03",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Army Plate and Frame Filter Press",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_280_03_2003.pdf",
#   "pages": 136,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-200: CIVIL / GEOTECHNICAL / LANDSCAPE ARCHITECTURE",
#   "status": "Inactive",
#   "publish_date": "07/23/2003",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_280_03_2003.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-280-03",
#   "summary": "This UFC was written to provide procedures for engineering and design, and to provide a format for documenting the engineering and design, of plate and frame filter press systems.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-280-03",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-280-04 Army Filtration of Liquids",
#   "ufc_number": "3-280-04",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Army Filtration of Liquids",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_280_04_2003.pdf",
#   "pages": 134,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-200: CIVIL / GEOTECHNICAL / LANDSCAPE ARCHITECTURE",
#   "status": "Inactive",
#   "publish_date": "12/17/2003",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_280_04_2003.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-280-04",
#   "summary": "This UFC addresses various solid\u2013liquid filtration systems, their associated filtration media, the use of various filtration process technologies, equipment and component specifications and design, available manufacturers and equipment sources, advantages and disadvantages of different filtration systems, solids disposal, costs, operational requirements (O&M), and safety considerations. The described equipment can be installed alone or at various stages in an overall treatment process, depending on application-specific needs.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-280-04",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-03AN Weapons Effects: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2, INACTIVE with No Replacement",
#   "ufc_number": "3-350-03AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Weapons Effects: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2, INACTIVE with No Replacement",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_03an_2005_c2.pdf",
#   "pages": 4,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_03an_2005_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-03-an-c2",
#   "summary": "The text of this UFC is the previous TM 5-858-2, dated 6 July 1984. The document is available only in hard copy form and only from.National Technical Information Service (NTIS)5285 Port Royal Road, Springfield, VA 22161Telephone 1-800-584-8332NTIS",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-03AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-04AN Structures: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_number": "3-350-04AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Structures: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_04an_2005_c2.pdf",
#   "pages": 4,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": "04/08/2009",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_04an_2005_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-04an",
#   "summary": "The text of this UFC is the previous TM 5-858-3, dated 6 July 1984. The document is available only in hard copy form and only from:National Technical Information Service (NTIS)5285 Port Royal Road, Springfield, VA 22161Telephone 1-888-584-8332NTIS.gov",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-04AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-05AN Shock Isolation Systems: Designing Facilities to Resist Nuclear Weapon Effects, INACTIVE with No Replacement",
#   "ufc_number": "3-350-05AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Shock Isolation Systems: Designing Facilities to Resist Nuclear Weapon Effects, INACTIVE with No Replacement",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_05an_2005_c2.pdf",
#   "pages": 4,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_05an_2005_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-05-an-c2",
#   "summary": "The text of this UFC is the previous TM 5-858-4, dated 11 June 1984. The document is available only in hard copy form and only from:National Technical Information Service (NTIS)5285 Port Royal Road, Springfield, VA 22161Telephone 1-888-584-8332NTIS.gov",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-05AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-05AN Shock Isolation Systems: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_number": "3-350-05AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Shock Isolation Systems: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_05an_2005_c2.pdf",
#   "pages": 4,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": "04/08/2009",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_05an_2005_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-05an",
#   "summary": "The text of this UFC is the previous TM 5-858-4, dated 11 June 1984. The document is available only in hard copy form and only from:National Technical Information Service (NTIS)5285 Port Royal Road, Springfield, VA 22161Telephone 1-888-584-8332NTIS.gov",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-05AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-06AN Air Entrapment, Fasteners, Penetration Protection, Hydraulic-Surge Protection Devices and EMP Protective Devices: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_number": "3-350-06AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Air Entrapment, Fasteners, Penetration Protection, Hydraulic-Surge Protection Devices and EMP Protective Devices: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_06an_2005_c2.pdf",
#   "pages": 4,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": "04/08/2009",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_06an_2005_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-06an",
#   "summary": "The text of this UFC is the previous TM 5-858-5, dated 15 December 1983. The document is available only in hard copy form and only from:National Technical Information Service (NTIS)5285 Port Royal Road, Springfield, VA 22161Telephone 1-888-584-8332NTIS.gov",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-06AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-07AN Hardness Verification: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_number": "3-350-07AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Hardness Verification: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_07an_2005_c2.pdf",
#   "pages": 4,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": "04/08/2009",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_07an_2005_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-07-an",
#   "summary": "National Technical Information Service (NTIS)5285 Port Royal Road, Springfield, VA 22161Telephone 1-888-584-8332NTIS.gov",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-07AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-08AN Facilities Support Systems: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_number": "3-350-08AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Facilities Support Systems: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_08an_2005_c2.pdf",
#   "pages": 37,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": "04/08/2009",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_08an_2005_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-08-an",
#   "summary": "The purpose of this series of manuals\u2019 is to provide guidance to engineers engaged in designing facilities that are required to resist nuclear weapon effects. It has been written for systems, structural, mechanical, electrical, and test engineers possessing state-of-the-art expertise in their respective disciplines, but having little knowledge of nuclear weapon effects on facilities. While it is applicable as general design guidelines to all Corps of Engineers specialists who participate in designing permanent military facilities, it has been written and organized on the assumption a systems engineering group will coordinate design of the facilities.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-08AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-09AN Illustrative Examples: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_number": "3-350-09AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Illustrative Examples: Designing Facilities to Resist Nuclear Weapon Effects, with Change 2",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_09an_2005_c2.pdf",
#   "pages": 4,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": "04/08/2009",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_09an_2005_c2.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-09an",
#   "summary": "The text of this UFC is the previous TM 5-858-8, dated 14 August 1985. The document is available only in hard copy form and only from:National Technical Information Service (NTIS)5285 Port Royal Road, Springfield, VA 22161Telephone 1-888-584-8332NTIS.gov",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-09AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-350-10AN Facilities System Engineering: Designing Facilities to Resist Nuclear Weapon Effects, with Change 1",
#   "ufc_number": "3-350-10AN",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Facilities System Engineering: Designing Facilities to Resist Nuclear Weapon Effects, with Change 1",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_350_10an_2009_c1.pdf",
#   "pages": 4,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-300: STRUCTURAL AND SEISMIC DESIGN",
#   "status": "Inactive",
#   "publish_date": "01/07/2009",
#   "change_date": "04/08/2009",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_350_10an_2009_c1.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-350-10an",
#   "summary": "The text of this UFC is the previous TM 5-858-1, dated 31 October 1983. The document is available only in hard copy form and only from:National Technical Information Service (NTIS)Telephone 1-888-584-8332NTIS.gov",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-350-10AN",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-410-05N Heating Systems Operation and Maintenance",
#   "ufc_number": "3-410-05N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Heating Systems Operation and Maintenance",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_410_05n_2004.pdf",
#   "pages": 282,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_410_05n_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-410-05n",
#   "summary": "This UFC is comprised of two sections. Chapter 1 introduces this UFC and provides a listing of references to other Tri-Service documents closely related to the subject. Appendix A contains the full text copy of the previously released Military Handbook (MIL-HDBK) on this subject. This UFC serves as criteria until such time as the full text UFC is developed from the MIL-HDBK and other sources.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-410-05N",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-410-06N Central Heating Plants Operation and Maintenance",
#   "ufc_number": "3-410-06N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Central Heating Plants Operation and Maintenance",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_410_06n_2004.pdf",
#   "pages": 386,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_410_06n_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-410-06n",
#   "summary": "This UFC is comprised of two sections.  Chapter 1 introduces this UFC. Appendix A contains the full text copy of the previously released Military Handbook (MIL-HDBK) on this subject. This UFC serves as criteria until such time as the full text UFC is developed from the MIL-HDBK and other sources.  This UFC provides general criteria for operating and maintaining heating systems.  Note that this document does not constitute a detailed technical design, and is issued as a general guide to the considerations associated with operating and maintaining heating systems.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-410-06N",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-430-02FA Central Steam Boiler Plants, with Change 1",
#   "ufc_number": "3-430-02FA",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Central Steam Boiler Plants, with Change 1",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_430_02fa_2003_c1.pdf",
#   "pages": 134,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "05/15/2003",
#   "change_date": "12/01/2007",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_430_02fa_2003_c1.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-430-02fa",
#   "summary": "Made INACTIVE 9 SEP 2024",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-430-02FA",
#   "superseded_versions": [
#     {
#       "title": "UFC 3-430-02FA Central Steam Boiler Plants",
#       "url": "https://www.wbdg.org/FFC/DOD/UFC/ARCHIVES/ufc_3_430_02fa_2003.pdf",
#       "date": "05-15-2003",
#       "filename": "ufc_3_430_02fa_2003.pdf"
#     }
#   ],
#   "superseded_versions_count": 1
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-430-03 Air Pollution Control Systems for Boiler and Incinerators",
#   "ufc_number": "3-430-03",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Air Pollution Control Systems for Boiler and Incinerators",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_430_03_2003.pdf",
#   "pages": 122,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "05/15/2003",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_430_03_2003.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-430-03",
#   "summary": "This manual is designed to facilitate the identification of air pollutant emission rates, and the selection of control equipment required to meet local, state, and federal compliance levels. Presented herein are fuel classifications, burning equipment types, emission rate factors, emission measuring techniques, control equipment ment types, and control methods. Also included are discussions of stack dispersion techniques, and control equipment selection.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-430-03",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-430-04FA High Temperature Water Heating Systems",
#   "ufc_number": "3-430-04FA",
#   "ufc_prefix": "UFC",
#   "ufc_title": "High Temperature Water Heating Systems",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_430_04fa_2003.pdf",
#   "pages": 64,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "05/15/2003",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_430_04fa_2003.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-430-04fa",
#   "summary": "This manual provides guidance for the design of high temperature water (HTW) heating systems classified as operating with supply water temperature above 240 degrees F. and designed to a pressure rating of 300 psi.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-430-04FA",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-430-07 Operations and Maintenance:  Inspection and Certification of Boilers and Unfired Pressure Vessels, with Change 5",
#   "ufc_number": "3-430-07",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Operations and Maintenance:  Inspection and Certification of Boilers and Unfired Pressure Vessels, with Change 5",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_430_07_2003_c5.pdf",
#   "pages": 88,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "07/24/2003",
#   "change_date": "05/07/2019",
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_430_07_2003_c5.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-430-07",
#   "summary": "The Department of the Navy (DON), including the Naval Shore Establishment and the Marine Corps, will use this UFC. It presents basic operation and maintenance guidance on inspection and certification of boilers and unfired pressure vessels.\\5\\ The Army will use documents that are referenced in paragraph 1-1.1 below entitled \"Army Criteria.\" The Air Force will use documents that are referenced in paragraph 1-1.2 below entitled \"Air Force Criteria.\" The Army and the Air Force will not need to refer to the remainder of this UFC. /5/.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-430-07",
#   "superseded_versions": [
#     {
#       "title": "UFC 3-430-07 Ops and Maint: Insp and Cert of Boilers and Unfired Press. Vessels, w Chg 4",
#       "url": "https://www.wbdg.org/FFC/DOD/UFC/ARCHIVES/ufc_3_430_07_2003_c4.pdf",
#       "date": "03-24-2014",
#       "filename": "ufc_3_430_07_2003_c4.pdf"
#     },
#     {
#       "title": "UFC 3-430-07 Ops and Maint: Insp and Cert of Boilers and Unfired Press. Vessels, w Chg 3",
#       "url": "https://www.wbdg.org/FFC/DOD/UFC/ARCHIVES/ufc_3_430_07_2003_c3.pdf",
#       "date": "05-01-2007",
#       "filename": "ufc_3_430_07_2003_c3.pdf"
#     },
#     {
#       "title": "UFC 3-430-07 Ops and Maint: Insp and Cert of Boilers and Unfired Press. Vessels, w Chg 2",
#       "url": "https://www.wbdg.org/FFC/DOD/UFC/ARCHIVES/ufc_3_430_07_2003_c2.pdf",
#       "date": "03-01-2005",
#       "filename": "ufc_3_430_07_2003_c2.pdf"
#     },
#     {
#       "title": "UFC 3-430-07 Ops and Maint: Insp and Cert of Boilers and Unfired Press. Vessels, w Chg 1",
#       "url": "https://www.wbdg.org/FFC/DOD/UFC/ARCHIVES/ufc_3_430_07_2003_c1.pdf",
#       "date": "01-01-2004",
#       "filename": "ufc_3_430_07_2003_c1.pdf"
#     },
#     {
#       "title": "UFC 3-430-07 Ops and Maint: Insp and Cert of Boilers and Unfired Press. Vessels",
#       "url": "https://www.wbdg.org/FFC/DOD/UFC/ARCHIVES/ufc_3_430_07_2003.pdf",
#       "date": "07-24-2003",
#       "filename": "ufc_3_430_07_2003.pdf"
#     }
#   ],
#   "superseded_versions_count": 5
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-430-08N Central Heating Plants",
#   "ufc_number": "3-430-08N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Central Heating Plants",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_430_08n_2004.pdf",
#   "pages": 230,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_430_08n_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-430-08n",
#   "summary": "INACTIVE as of 12 SEP 2024",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-430-08N",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-440-02N Water Conservation Operation and Maintenance",
#   "ufc_number": "3-440-02N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Water Conservation Operation and Maintenance",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_440_02n_2004.pdf",
#   "pages": 143,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_440_02n_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-440-02n",
#   "summary": "This UFC is comprised of two sections.  Chapter 1 introduces this UFC and provides a listing of references to other Tri-Service documents closely related to the subject. Appendix A contains the full text copy of the previously released Military Handbook (MIL-HDBK) on this subject. This UFC serves as criteria until such time as the full text UFC is developed from the MIL-HDBK and other sources.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-440-02N",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-440-03N Passive Solar Buildings",
#   "ufc_number": "3-440-03N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Passive Solar Buildings",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_440_03n_2004.pdf",
#   "pages": 201,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_440_03n_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-440-03n",
#   "summary": "This UFC is comprised of two sections. Chapter 1 introduces this UFC and provides a listing of references to other Tri-Service documents closely related to the subject. Appendix A contains the full text copy of the previously released Military Handbook (MIL-HDBK) on this subject. This UFC serves as criteria until such time as the full text UFC is developed from the MIL-HDBK and other sources.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-440-03N",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-440-06N Cooling Buildings by Natural Ventilation",
#   "ufc_number": "3-440-06N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Cooling Buildings by Natural Ventilation",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_440_06n_2004.pdf",
#   "pages": 183,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_440_06n_2004.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-440-06n",
#   "summary": "This UFC is comprised of two sections. Chapter 1 introduces this UFC and provides a listing of references to other Tri-Service documents closely related to the subject. Appendix A contains the full text copy of the previously released Military Handbook (MIL-HDBK) on this subject. This UFC serves as criteria until such time as the full text UFC is developed from the MIL-HDBK and other sources.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-440-06N",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-450-02 Power Plant Acoustics",
#   "ufc_number": "3-450-02",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Power Plant Acoustics",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_450_02_2003.pdf",
#   "pages": 97,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "05/15/2003",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_450_02_2003.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-450-02",
#   "summary": "This manual provides noise control data and analysis procedures for design and construction of diesel, gas, and gas turbine engine facilities at military installations in the continental United States (CONUS) and for U.S. military facilities around the world. The data and procedures are directed primarily toward the control of noise from enginedriven electric generators but are equally appropriate for any power system using reciprocating orturbine\u2019 engines. This manual applies to all new construction and to major alterations of existing structures. U.S. military facilities that require higher standards because of special functions or missions are not covered in this manual; criteria and standards for these exceptions are normally contained in design directives for the particular facilities. If procedures given in this manual do not provide all the functional and structural needs of a project, recognized construction practices and design standards can be used.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-450-02",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-490-03FA High-Pressure Gas and Cryogenic Systems",
#   "ufc_number": "3-490-03FA",
#   "ufc_prefix": "UFC",
#   "ufc_title": "High-Pressure Gas and Cryogenic Systems",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_490_03fa_2005.pdf",
#   "pages": 72,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "03/01/2005",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_490_03fa_2005.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-490-03fa",
#   "summary": "This manual provides guidance applicable to the design of high-pressure gas and cryogenic systems.  The intent is to supply the user with a relevant and current list of references to handbooks and codes and to highlight the design considerations.  Where possible, data and guidance are offered in tabular ofrm for easy access.  Examples are specifically excluded so that the designer will be forced to use the latest versions of the cited references which contain, amoung other things, detalied solutions to standard problems displaying limitations and caveats.  A reference list is given in appendix A.  Trade names for various products have been used in the manual to afford the designer the descriptive information generally associated with such names.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-490-03FA",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-490-04A Indoor Radon Prevention and Mitigation",
#   "ufc_number": "3-490-04A",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Indoor Radon Prevention and Mitigation",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_490_04a_2003.pdf",
#   "pages": 42,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-400: MECHANICAL",
#   "status": "Inactive",
#   "publish_date": "05/15/2003",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
#   "download_link": "https://www.wbdg.org/FFC/DOD/UFC/INACTIVE/ufc_3_490_04a_2003.pdf",
#   "metadata_link": "https://www.wbdg.org/dod/ufc/ufc-3-490-04a",
#   "summary": "This document establishes design criteria for all U.S. Army facilities to reduce health risks due to indoor radon. The design standards established herein are applicable to all newly constructed and substantially altered Army facilities both inside and outside the Continental United States.",
#   "ccr_url": "https://cms.wbdg.org/ccrs/new?ufc=3-490-04A",
#   "superseded_versions": [],
#   "superseded_versions_count": 0
# }
# [DEBUG] {
#   "ufc_full_name": "UFC 3-540-02N Steam Power Plants",
#   "ufc_number": "3-540-02N",
#   "ufc_prefix": "UFC",
#   "ufc_title": "Steam Power Plants",
#   "ufc_type": "UFC",
#   "filename": "ufc_3_540_02n_2004.pdf",
#   "pages": 313,
#   "series": "3 - DISCIPLINE-SPECIFIC CRITERIA | 3-500: ELECTRICAL",
#   "status": "Inactive",
#   "publish_date": "01/16/2004",
#   "change_date": null,
#   "archived / rescinded date": null,
#   "replaced_by": null,
# ...
# [DEBUG] [86/371] ✅ Downloaded: ufc_3_555_01_2024.pdf
# [DEBUG] [87/371] ✅ Downloaded: ufc_3_560_01_2017_c3.pdf
# [DEBUG] [88/371] ✅ Downloaded: ufc_3_570_01_c1_2016.pdf
# [DEBUG] [89/371] ✅ Downloaded: ufc_3_570_06_2019.pdf
# [DEBUG] [90/371] ✅ Downloaded: ufc_3_575_01_2012_c1.pdf
# [DEBUG] [91/371] ✅ Downloaded: ufc_3_580_01_2024.pdf
# [DEBUG] [92/371] ✅ Downloaded: ufc_3_600_01_2016_c6.pdf
# [DEBUG] [93/371] ✅ Downloaded: ufc_3_601_02_2021_c1.pdf
# [DEBUG] [94/371] ✅ Downloaded: ufc_3_701_01_2022_c7.pdf
# [DEBUG] [95/371] ✅ Downloaded: ufc_3_730_01_2024.pdf
# [DEBUG] [96/371] ✅ Downloaded: ufc_3_740_05_2022.pdf
# [DEBUG] [97/371] ✅ Downloaded: ufc_3_810_01n_2016_c3.pdf
# [DEBUG] [98/371] ✅ Downloaded: ufc_4_010_01_2018_c3.pdf
# [DEBUG] [99/371] ✅ Downloaded: ufc_4_010_05_2023.pdf
# [DEBUG] [100/371] ✅ Downloaded: ufc_4_010_06_2023.pdf
# [DEBUG] [101/371] ✅ Downloaded: ufc_4_020_01_2008.pdf
# [DEBUG] [102/371] ✅ Downloaded: ufc_4_021_01_2008_c1.pdf
# [DEBUG] [103/371] ✅ Downloaded: ufc_4_021_02_2013_c1.pdf
# [DEBUG] [104/371] ✅ Downloaded: ufc_4_022_01_2017.pdf
# [DEBUG] [105/371] ✅ Downloaded: ufc_4_022_02_2009_c1.pdf
# [DEBUG] [106/371] ✅ Downloaded: ufc_4_022_03_2013.pdf
# [DEBUG] [107/371] ✅ Downloaded: ufc_4_023_03_2009_c4.pdf
# [DEBUG] [108/371] ✅ Downloaded: ufc_4_023_07_2008_c1.pdf
# [DEBUG] [109/371] ✅ Downloaded: ufc_4_023_10_2016.pdf
# [DEBUG] [110/371] ✅ Downloaded: ufc_4_025_01_2012.pdf
# [DEBUG] [111/371] ✅ Downloaded: ufc_4_026_01_2020.pdf
# [DEBUG] [113/371] ✅ Downloaded: ufc_4_133_01_2016_c2.pdf
# [DEBUG] [114/371] ✅ Downloaded: ufc_4_141_03_2024.pdf
# [DEBUG] [115/371] ✅ Downloaded: ufc_4_141_10_2022.pdf
# [DEBUG] [116/371] ✅ Downloaded: ufc_4_150_02_2020.pdf
# [DEBUG] [117/371] ✅ Downloaded: ufc_4_150_06_2001_c1.pdf
# [DEBUG] [118/371] ✅ Downloaded: ufc_4_150_07_2001_c1.pdf
# [DEBUG] [119/371] ✅ Downloaded: ufc_4_150_08_2020.pdf
# [DEBUG] [120/371] ✅ Downloaded: ufc_4_150_09_2019.pdf
# [DEBUG] [121/371] ✅ Downloaded: ufc_4_151_10_2001_c1.pdf
# [DEBUG] [122/371] ✅ Downloaded: ufc_4_152_01_2017_c1.pdf
# [DEBUG] [123/371] ✅ Downloaded: ufc_4_152_07_2009_c1.pdf
# [DEBUG] [124/371] ✅ Downloaded: ufc_4_159_03_2020.pdf
# [DEBUG] [125/371] ✅ Downloaded: fc_4_171_06n_2014.pdf
# [DEBUG] [126/371] ✅ Downloaded: ufc_4_179_02_2020_c1.pdf
# [DEBUG] [127/371] ✅ Downloaded: fc_4_179_03f_2015_c2.pdf
# [DEBUG] [128/371] ✅ Downloaded: ufc_4_211_01_2017_c3.pdf
# [DEBUG] [129/371] ✅ Downloaded: ufc_4_211_02_2012.pdf
# [DEBUG] [130/371] ✅ Downloaded: fc_4_211_03f_2016.pdf
# [DEBUG] [131/371] ✅ Downloaded: ufc_4_213_10_2020.pdf
# [DEBUG] [132/371] ✅ Downloaded: ufc_4_214_03_2018.pdf
# [DEBUG] [133/371] ✅ Downloaded: ufc_4_215_01_2014.pdf
# [DEBUG] [134/371] ✅ Downloaded: fc_4_218_01f_2015_c2.pdf
# [DEBUG] [135/371] ✅ Downloaded: ufc_4_310_03_2020.pdf
# [DEBUG] [136/371] ✅ Downloaded: ufc_4_420_01_2025.pdf
# [DEBUG] [137/371] ✅ Downloaded: fc_4_420_07f_2018.pdf
# [DEBUG] [138/371] ✅ Downloaded: ufc_4_440_01_2014_c1.pdf
# [DEBUG] [139/371] ✅ Downloaded: ufc_4_510_01_2023_c4.pdf
# [DEBUG] [140/371] ✅ Downloaded: ufc_4_610_01_2021_c1.pdf
# [DEBUG] [141/371] ✅ Downloaded: fc_4_610_04f_2015.pdf
# [DEBUG] [142/371] ✅ Downloaded: ufc_4_711_01_2018_c3.pdf
# [DEBUG] [143/371] ✅ Downloaded: ufc_4_720_01_2012.pdf
# [DEBUG] [144/371] ✅ Downloaded: fc_4_721_10n_2022_c1.pdf
# [DEBUG] [145/371] ✅ Downloaded: ufc_4_722_01_2023.pdf
# [DEBUG] [146/371] ✅ Downloaded: ufc_4_730_01_2023.pdf
# [DEBUG] [147/371] ✅ Downloaded: ufc_4_730_10_2019_c1.pdf
# [DEBUG] [148/371] ✅ Downloaded: ufc_4_740_02_c1_2019.pdf
# [DEBUG] [149/371] ✅ Downloaded: ufc_4_740_06_2006_c1.pdf
# [DEBUG] [150/371] ✅ Downloaded: fc_4_740_14n_2014.pdf
# [DEBUG] [151/371] ✅ Downloaded: ufc_4_740_15_2011.pdf
# [DEBUG] [152/371] ✅ Downloaded: ufc_4_740_20_2023.pdf
# [DEBUG] [153/371] ✅ Downloaded: ufc_4_750_07_2020.pdf
# [DEBUG] [154/371] ✅ Downloaded: fc_4_760_10n_2013.pdf
# [DEBUG] [155/371] ✅ Downloaded: ufc_4_826_10_2024.pdf
# [DEBUG] [156/371] ✅ Downloaded: ufc_4_860_01_2022.pdf
# [DEBUG] [157/371] ✅ Downloaded: ufc_4_860_03_2008.pdf
# [DEBUG] [158/371] ✅ Downloaded: ufc_1_300_05a_2004.pdf
# [DEBUG] [159/371] ✅ Downloaded: ufc_1_300_07a_2005.pdf
# [DEBUG] [160/371] ✅ Downloaded: ufc_2_000_01_2004.pdf
# [DEBUG] [161/371] ✅ Downloaded: ufc_3_130_04_2004.pdf
# [DEBUG] [162/371] ✅ Downloaded: ufc_3_130_07_2004.pdf
# [DEBUG] [163/371] ✅ Downloaded: ufc_3_190_03a_2003.pdf
# [DEBUG] [164/371] ✅ Downloaded: ufc_3_190_07n_2004.pdf
# [DEBUG] [165/371] ✅ Downloaded: ufc_3_210_04_2004.pdf
# [DEBUG] [166/371] ✅ Downloaded: ufc_3_220_04fa_2004.pdf
# [DEBUG] [167/371] ✅ Downloaded: ufc_3_220_05_2004.pdf
# [DEBUG] [168/371] ✅ Downloaded: ufc_3_220_06_2004.pdf
# [DEBUG] [169/371] ✅ Downloaded: ufc_3_220_08fa_2004.pdf
# [DEBUG] [170/371] ✅ Downloaded: ufc_3_230_06a_2004_c2.pdf
# [DEBUG] [171/371] ✅ Downloaded: ufc_3_240_03n_2004.pdf
# [DEBUG] [172/371] ✅ Downloaded: ufc_3_240_05a_2004.pdf
# [DEBUG] [173/371] ✅ Downloaded: ufc_3_240_10a_2004.pdf
# [DEBUG] [174/371] ✅ Downloaded: ufc_3_250_10fa_2004.pdf
# [DEBUG] [175/371] ✅ Downloaded: ufc_3_280_01a_2004.pdf
# [DEBUG] [176/371] ✅ Downloaded: ufc_3_280_03_2003.pdf
# [DEBUG] [177/371] ✅ Downloaded: ufc_3_280_04_2003.pdf
# [DEBUG] [178/371] ✅ Downloaded: ufc_3_350_03an_2005_c2.pdf
# [DEBUG] [179/371] ✅ Downloaded: ufc_3_350_04an_2005_c2.pdf
# [DEBUG] [180/371] ✅ Downloaded: ufc_3_350_05an_2005_c2.pdf
# [DEBUG] [181/371] ⏭️ Skipped (exists): ufc_3_350_05an_2005_c2.pdf
# [DEBUG] [182/371] ✅ Downloaded: ufc_3_350_06an_2005_c2.pdf
# [DEBUG] [183/371] ✅ Downloaded: ufc_3_350_07an_2005_c2.pdf
# [DEBUG] [184/371] ✅ Downloaded: ufc_3_350_08an_2005_c2.pdf
# [DEBUG] [185/371] ✅ Downloaded: ufc_3_350_09an_2005_c2.pdf
# [DEBUG] [186/371] ✅ Downloaded: ufc_3_350_10an_2009_c1.pdf
# [DEBUG] [187/371] ✅ Downloaded: ufc_3_410_05n_2004.pdf
# [DEBUG] [188/371] ✅ Downloaded: ufc_3_410_06n_2004.pdf
# [DEBUG] [189/371] ✅ Downloaded: ufc_3_430_02fa_2003_c1.pdf
# [DEBUG] [190/371] ✅ Downloaded: ufc_3_430_03_2003.pdf
# [DEBUG] [191/371] ✅ Downloaded: ufc_3_430_04fa_2003.pdf
# [DEBUG] [192/371] ✅ Downloaded: ufc_3_430_07_2003_c5.pdf
# [DEBUG] [193/371] ✅ Downloaded: ufc_3_430_08n_2004.pdf
# [DEBUG] [194/371] ✅ Downloaded: ufc_3_440_02n_2004.pdf
# [DEBUG] [195/371] ✅ Downloaded: ufc_3_440_03n_2004.pdf
# [DEBUG] [196/371] ✅ Downloaded: ufc_3_440_06n_2004.pdf
# [DEBUG] [197/371] ✅ Downloaded: ufc_3_450_02_2003.pdf
# [DEBUG] [198/371] ✅ Downloaded: ufc_3_490_03fa_2005.pdf
# [DEBUG] [199/371] ✅ Downloaded: ufc_3_490_04a_2003.pdf
# [DEBUG] [200/371] ✅ Downloaded: ufc_3_540_02n_2004.pdf
# [DEBUG] [201/371] ✅ Downloaded: ufc_4_010_03_2011.pdf
# [DEBUG] [202/371] ✅ Downloaded: ufc_4_020_02fa_2005.pdf
# [DEBUG] [203/371] ✅ Downloaded: ufc_4_024_01_2008.pdf
# [DEBUG] [204/371] ✅ Downloaded: ufc_4_141_04_2008_c1.pdf
# [DEBUG] [205/371] ✅ Downloaded: fc_4_141_05n_2015_c1.pdf
# [DEBUG] [206/371] ✅ Downloaded: ufc_4_159_01n_2004.pdf
# [DEBUG] [207/371] ✅ Downloaded: ufc_4_171_01n_2004.pdf
# [DEBUG] [208/371] ✅ Downloaded: ufc_4_171_02a_2005.pdf
# [DEBUG] [209/371] ✅ Downloaded: ufc_4_171_05_2005_c3.pdf
# [DEBUG] [210/371] ✅ Downloaded: ufc_4_179_01_2004.pdf
# [DEBUG] [211/371] ✅ Downloaded: ufc_4_212_01n_2006_c4.pdf
# [DEBUG] [212/371] ✅ Downloaded: ufc_4_213_12_2003.pdf
# [DEBUG] [213/371] ✅ Downloaded: ufc_4_214_02_2003.pdf
# [DEBUG] [214/371] ✅ Downloaded: ufc_4_216_02_2004.pdf
# [DEBUG] [215/371] ✅ Downloaded: ufc_4_218_10n_2004.pdf
# [DEBUG] [216/371] ✅ Downloaded: ufc_4_229_01n_2004.pdf
# [DEBUG] [217/371] ✅ Downloaded: ufc_4_310_02n_2004.pdf
# [DEBUG] [218/371] ✅ Downloaded: ufc_4_390_01_2003.pdf
# [DEBUG] [219/371] ✅ Downloaded: ufc_4_451_10n_2004.pdf
# [DEBUG] [220/371] ✅ Downloaded: ufc_4_721_01a_2005.pdf
# [DEBUG] [221/371] ✅ Downloaded: ufc_4_721_11.1_2002.pdf
# [DEBUG] [222/371] ✅ Downloaded: ufc_4_730_02n_2004.pdf
# [DEBUG] [223/371] ✅ Downloaded: ufc_4_730_03_2005.pdf
# [DEBUG] [224/371] ✅ Downloaded: ufc_4_730_04an_2005.pdf
# [DEBUG] [225/371] ✅ Downloaded: ufc_4_730_09a_2005.pdf
# [DEBUG] [226/371] ✅ Downloaded: ufc_4_740_08an_2005.pdf
# [DEBUG] [227/371] ✅ Downloaded: ufc_4_740_01nf_2004.pdf
# [DEBUG] [228/371] ✅ Downloaded: ufc_4_740_03_2002.pdf
# [DEBUG] [229/371] ✅ Downloaded: ufc_4_740_09an_2005.pdf
# [DEBUG] [230/371] ✅ Downloaded: ufc_4_740_10an_2005.pdf
# [DEBUG] [231/371] ✅ Downloaded: ufc_4_740_11an_2005.pdf
# [DEBUG] [232/371] ✅ Downloaded: ufc_4_740_12an_2005.pdf
# [DEBUG] [233/371] ✅ Downloaded: ufc_4_740_14_2002.pdf
# [DEBUG] [234/371] ✅ Downloaded: ufc_4_740_16_2005.pdf
# [DEBUG] [235/371] ✅ Downloaded: ufc_4_740_18an_2005.pdf
# [DEBUG] [236/371] ✅ Downloaded: ufc_4_750_01nf_2004.pdf
# [DEBUG] [237/371] ✅ Downloaded: ufc_4_750_02n_2003.pdf
# [DEBUG] [238/371] ✅ Downloaded: ufc_4_860_02n_2004.pdf
# [DEBUG] [239/371] ✅ Downloaded: ufc_4_911_01n_2004.pdf
# [DEBUG] [240/371] ✅ Downloaded: ufc_1_202_01_2013.pdf
# [DEBUG] [241/371] ✅ Downloaded: ufc_1_900_01_2002.pdf
# [DEBUG] [242/371] ✅ Downloaded: ufc_2_000_02an_2005.pdf
# [DEBUG] [243/371] ✅ Downloaded: ufc_3_110_04_2007.pdf
# [DEBUG] [244/371] ✅ Downloaded: ufc_3_130_06_2004.pdf
# [DEBUG] [245/371] ✅ Downloaded: ufc_3_190_01fa_2003.pdf
# [DEBUG] [246/371] ✅ Downloaded: ufc_3_190_02fa.pdf
# [DEBUG] [247/371] ✅ Downloaded: ufc_3_190_04fa.pdf
# [DEBUG] [248/371] ✅ Downloaded: ufc_3_210_01a_2004.pdf
# [DEBUG] [249/371] ✅ Downloaded: ufc_3_210_02_2004_c1.pdf
# [DEBUG] [250/371] ✅ Downloaded: ufc_3_210_03a_2004.pdf
# [DEBUG] [251/371] ✅ Downloaded: ufc_3_210_05fa.pdf
# [DEBUG] [252/371] ✅ Downloaded: ufc_3_210_06a_2006.pdf
# [DEBUG] [253/371] ✅ Downloaded: ufc_3_220_01a_2004.pdf
# [DEBUG] [254/371] ✅ Downloaded: ufc_3_220_01n_2005.pdf
# [DEBUG] [255/371] ✅ Downloaded: ufc_3_220_02_2004.pdf
# [DEBUG] [256/371] ✅ Downloaded: ufc_3_220_03fa_2004.pdf
# [DEBUG] [257/371] ✅ Downloaded: ufc_3_220_07_2004.pdf
# [DEBUG] [258/371] ✅ Downloaded: ufc_3_230_03a_2004.pdf
# [DEBUG] [259/371] ✅ Downloaded: ufc_3_230_04a_2004.pdf
# [DEBUG] [260/371] ✅ Downloaded: ufc_3_230_07a_2004.pdf
# [DEBUG] [261/371] ✅ Downloaded: ufc_3_230_08a_2004.pdf
# [DEBUG] [262/371] ✅ Downloaded: ufc_3_230_09a_2004.pdf
# [DEBUG] [263/371] ✅ Downloaded: ufc_3_230_10a_2004.pdf
# [DEBUG] [264/371] ✅ Downloaded: ufc_3_230_11a_2004.pdf
# [DEBUG] [265/371] ✅ Downloaded: ufc_3_230_12a_2004.pdf
# [DEBUG] [266/371] ✅ Downloaded: ufc_3_230_13a_2004.pdf
# [DEBUG] [267/371] ✅ Downloaded: ufc_3_230_14a_2004.pdf
# [DEBUG] [268/371] ✅ Downloaded: ufc_3_230_15fa_2004.pdf
# [DEBUG] [269/371] ✅ Downloaded: ufc_3_230_16fa_2004.pdf
# [DEBUG] [270/371] ✅ Downloaded: ufc_3_230_17fa_2004.pdf
# [DEBUG] [271/371] ✅ Downloaded: ufc_3_230_19n_2005.pdf
# [DEBUG] [272/371] ✅ Downloaded: ufc_3_240_02_2012_c1.pdf
# [DEBUG] [273/371] ✅ Downloaded: ufc_3_240_02n_2004.pdf
# [DEBUG] [274/371] ✅ Downloaded: ufc_3_240_04a_2004.pdf
# [DEBUG] [275/371] ✅ Downloaded: ufc_3_240_06a_2004.pdf
# [DEBUG] [276/371] ✅ Downloaded: ufc_3_240_07fa_2004.pdf
# [DEBUG] [277/371] ✅ Downloaded: ufc_3_240_08fa_2004.pdf
# [DEBUG] [278/371] ✅ Downloaded: ufc_3_240_09fa_2004.pdf
# [DEBUG] [279/371] ✅ Downloaded: ufc_3_240_14n_2004.pdf
# [DEBUG] [280/371] ✅ Downloaded: ufc_3_250_01fa_2004.pdf
# [DEBUG] [281/371] ✅ Downloaded: ufc_3_250_04fa_2004.pdf
# [DEBUG] [282/371] ✅ Downloaded: ufc_3_250_06_2004.pdf
# [DEBUG] [283/371] ✅ Downloaded: ufc_3_250_08fa_2004.pdf
# [DEBUG] [284/371] ✅ Downloaded: ufc_3_250_09fa_2004.pdf
# [DEBUG] [285/371] ✅ Downloaded: ufc_3_250_12n_2005.pdf
# [DEBUG] [286/371] ✅ Downloaded: ufc_3_250_18fa_2006.pdf
# [DEBUG] [287/371] ✅ Downloaded: ufc_3_260_01_2001.pdf
# [DEBUG] [288/371] ✅ Downloaded: ufc_3_260_05a_2004.pdf
# [DEBUG] [289/371] ✅ Downloaded: ufc_3_260_11fa_2005.pdf
# [DEBUG] [290/371] ✅ Downloaded: ufc_3_260_16fa_2004.pdf
# [DEBUG] [291/371] ✅ Downloaded: ufc_3_270_02_2001.pdf
# [DEBUG] [292/371] ✅ Downloaded: ufc_3_270_03_2001.pdf
# [DEBUG] [293/371] ✅ Downloaded: ufc_3_270_04_2001.pdf
# [DEBUG] [294/371] ✅ Downloaded: ufc_3_270_05_2001.pdf
# [DEBUG] [295/371] ✅ Downloaded: ufc_3_270_06_2001.pdf
# [DEBUG] [296/371] ✅ Downloaded: ufc_3_270_07_2002.pdf
# [DEBUG] [297/371] ✅ Downloaded: ufc_3_280_02a_2004.pdf
# [DEBUG] [298/371] ✅ Downloaded: ufc_3_300_10n_c2.pdf
# [DEBUG] [299/371] ✅ Downloaded: ufc_3_301_05a_2005.pdf
# [DEBUG] [300/371] ✅ Downloaded: ufc_3_310_01_2005_c2.pdf
# [DEBUG] [301/371] ✅ Downloaded: ufc_3_310_02a_2005.pdf
# [DEBUG] [302/371] ✅ Downloaded: ufc_3_310_03a_2005.pdf
# [DEBUG] [303/371] ✅ Downloaded: ufc_3_310_04_2013_c1.pdf
# [DEBUG] [304/371] ✅ Downloaded: ufc_3_310_05a_2005.pdf
# [DEBUG] [305/371] ✅ Downloaded: ufc_3_310_07a_2006.pdf
# [DEBUG] [306/371] ✅ Downloaded: ufc_3_320_01a_2005.pdf
# [DEBUG] [307/371] ✅ Downloaded: ufc_3_320_02a_2005.pdf
# [DEBUG] [308/371] ✅ Downloaded: ufc_3_320_03a_2005_c2.pdf
# [DEBUG] [309/371] ✅ Downloaded: ufc_3_320_04a_c2.pdf
# [DEBUG] [310/371] ✅ Downloaded: ufc_3_320_05a_2005.pdf
# [DEBUG] [311/371] ✅ Downloaded: ufc_3_320_06a_2005.pdf
# [DEBUG] [312/371] ✅ Downloaded: ufc_3_330_01a_2005.pdf
# [DEBUG] [313/371] ✅ Downloaded: ufc_3_330_02a_2005.pdf
# [DEBUG] [314/371] ✅ Downloaded: ufc_3_330_03a._2005.pdf
# [DEBUG] [315/371] ✅ Downloaded: ufc_3_340_02an.pdf
# [DEBUG] [316/371] ✅ Downloaded: ufc_3_340_03an_2005.pdf
# [DEBUG] [317/371] ✅ Downloaded: ufc_3_340_04an.pdf
# [DEBUG] [318/371] ✅ Downloaded: ufc_3_340_05an_2005.pdf
# [DEBUG] [319/371] ✅ Downloaded: ufc_3_340_05an.pdf
# [DEBUG] [320/371] ✅ Downloaded: ufc_3_340_06an.pdf
# [DEBUG] [321/371] ✅ Downloaded: ufc_3_340_07an.pdf
# [DEBUG] [322/371] ✅ Downloaded: ufc_3_340_09an.pdf
# [DEBUG] [323/371] ✅ Downloaded: ufc_3_340_10an.pdf
# [DEBUG] [324/371] ✅ Downloaded: ufc_3_340_13_2004.pdf
# [DEBUG] [325/371] ✅ Downloaded: ufc_3_400_01_2002_c4.pdf
# [DEBUG] [326/371] ✅ Downloaded: ufc_3_400_10n_2006_c1.pdf
# [DEBUG] [327/371] ✅ Downloaded: ufc_3_401_01fa_2005.pdf
# [DEBUG] [328/371] ✅ Downloaded: ufc_3_401_05n_2004.pdf
# [DEBUG] [329/371] ✅ Downloaded: ufc_3_410_01fa_2003_c4.pdf
# [DEBUG] [330/371] ✅ Downloaded: ufc_3_410_02a_2003_c1.pdf
# [DEBUG] [331/371] ✅ Downloaded: ufc_3_410_02n_2005.pdf
# [DEBUG] [332/371] ✅ Downloaded: ufc_3_410_03fa_2003_c1.pdf
# [DEBUG] [333/371] ✅ Downloaded: ufc_3_410_04n_2004.pdf
# [DEBUG] [334/371] ✅ Downloaded: ufc_3_430_05fa_2003.pdf
# [DEBUG] [335/371] ✅ Downloaded: ufc_3_430_09n_2004.pdf
# [DEBUG] [336/371] ✅ Downloaded: ufc_3_440_04n_2004.pdf
# [DEBUG] [337/371] ✅ Downloaded: ufc_3_440_05n_2004_c2.pdf
# [DEBUG] [338/371] ✅ Downloaded: ufc_3_501_03n_2004.pdf
# [DEBUG] [339/371] ✅ Downloaded: ufc_3_540_04n_2004.pdf
# [DEBUG] [340/371] ✅ Downloaded: ufc_3_550_03fa_2005.pdf
# [DEBUG] [341/371] ✅ Downloaded: ufc_3_550_03n_2004.pdf
# [DEBUG] [342/371] ✅ Downloaded: ufc_3_555_01n_2004.pdf
# [DEBUG] [343/371] ✅ Downloaded: ufc_3_560_10n_2004.pdf
# [DEBUG] [344/371] ✅ Downloaded: ufc_3_570_02a_2005.pdf
# [DEBUG] [345/371] ✅ Downloaded: ufc_3_570_02n_2004.pdf
# [DEBUG] [346/371] ✅ Downloaded: ufc_3_580_10_2004_c3.pdf
# [DEBUG] [347/371] ✅ Downloaded: ufc_3_700_01a_2005.pdf
# [DEBUG] [348/371] ✅ Downloaded: ufc_3_700_02a_2005.pdf
# [DEBUG] [349/371] ✅ Downloaded: ufc_3_710_01a_2005.pdf
# [DEBUG] [350/371] ✅ Downloaded: ufc_4_010_02_2012.pdf
# [DEBUG] [351/371] ✅ Downloaded: ufc_4_020_03fa_2005.pdf
# [DEBUG] [352/371] ✅ Downloaded: ufc_4_020_04fa_2005.pdf
# [DEBUG] [353/371] ✅ Downloaded: ufc_4_030_01_2007.pdf
# [DEBUG] [354/371] ✅ Downloaded: ufc_4_121_10n_2004.pdf
# [DEBUG] [355/371] ✅ Downloaded: ufc_4_133_01n_2005_c1-2.pdf
# [DEBUG] [356/371] ✅ Downloaded: ufc_4_211_01n_2004.pdf
# [DEBUG] [357/371] ✅ Downloaded: ufc_4_440_01a_2005.pdf
# [DEBUG] [358/371] ✅ Downloaded: ufc_4_610_02n_2005.pdf
# [DEBUG] [359/371] ✅ Downloaded: fc_4_721_02F_2015.pdf
# [DEBUG] [360/371] ✅ Downloaded: fc_4_722_01n_2013.pdf
# [DEBUG] [361/371] ✅ Downloaded: fc_4_722_01f_2007_c1.pdf
# [DEBUG] [362/371] ✅ Downloaded: fc_4_730_10n_2013.pdf
# [DEBUG] [363/371] ✅ Downloaded: fc_4_740_02f_2006_c1.pdf
# [DEBUG] [364/371] ✅ Downloaded: fc_4_740_02n_2014.pdf
# [DEBUG] [365/371] ✅ Downloaded: ufc_4_832_01n_2004.pdf
# [DEBUG] [366/371] ✅ Downloaded: ufc_4_211_02nf_2005.pdf
# [DEBUG] [367/371] ✅ Downloaded: ufc_4_442_01n_2004.pdf
# [DEBUG] [368/371] ✅ Downloaded: ufc_4_721_10_2002_c4.pdf
# [DEBUG] [369/371] ✅ Downloaded: UFC_Complete_1-200-01_thru_3-220-20.pdf
# [DEBUG] [370/371] ✅ Downloaded: UFC_Complete_3-230-01_thru_3-340-02.pdf
# [DEBUG] [371/371] ✅ Downloaded: UFC_Complete_3-400-02_thru_3-810-01N.pdf
# [DEBUG] [372/371] ✅ Downloaded: UFC_Complete_4-010-01_thru_4-159-03.pdf
# [DEBUG] [373/371] ✅ Downloaded: UFC_Complete_FC_4-171-06N_thru_4-860_03.pdf
# [DEBUG] 📦 All UFC files and metadata zipped.
